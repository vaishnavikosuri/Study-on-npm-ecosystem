# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import subprocess
import pandas as pd
import requests
from urllib.parse import urljoin
import sqlite3
import json
import time
from datetime import datetime, timedelta
import re
from google.colab import drive
import random

drive.mount('/content/gdrive/', force_remount=True)
os.chdir("/content/gdrive/Shareddrives/ECS 260/final")
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# # Funtion Definitions

# %%
def GET(json_obj, keys):
  if not isinstance(keys, list):
    keys = [keys]
  current = json_obj
  try:
    for key in keys:
      if isinstance(current, list):
        key = int(key)
      current = current[key]
    return current
  except (TypeError, IndexError, KeyError):
    return None

def isValid(value):
  if isinstance(value, list):
    return not len(value) == 0
  return value != None and value != ""

def getN(arr):
  return len(arr) if isValid(arr) else None

def extract_github_url(repo_url):
  if not isValid(repo_url):
    return None

  github_https_pattern = re.compile(r'https://github\.com/([^/]+/[^/]+)\.git')
  github_git_pattern = re.compile(r'git://github\.com/([^/]+/[^/]+)\.git')
  github_ssh_pattern = re.compile(r'git@github\.com:([^/]+/[^/]+)\.git')

  match_https = github_https_pattern.match(repo_url)
  match_git = github_git_pattern.match(repo_url)
  match_ssh = github_ssh_pattern.match(repo_url)

  if match_https:
    return f"https://github.com/{match_https.group(1)}"
  elif match_git:
    return f"https://github.com/{match_git.group(1)}"
  elif match_ssh:
    return f"https://github.com/{match_ssh.group(1)}"
  else:
    return None

# %%
# fetch json from an API endpoint
def fetch_response_without_fail(url, params = {}, headers = {}, shouldScrap = False):
  retry_count = 0
  max_retries = 15
  time_interval = 10
  status = ""
  while retry_count < max_retries:
    try:
      response = requests.get(url, params=params, headers=headers)

      if response.status_code == 200:
        status = str(response.status_code)
        if shouldScrap:
          return (status, response)
        else:
          return (status, response.json())
      elif response.status_code == 404:
        status = str(response.status_code)
        print(f"Error: {response.status_code}, skipping url {url}")
        return (status, None)
      else:
        status = str(response.status_code)
        print(f"Error: {response.status_code}")
        print(params)
        retry_count += 1
        print(f"Retrying in {time_interval} seconds... (Retry {retry_count}/{max_retries})")
        if response.status_code == 429:
          retry_after = response.headers.get('Retry-After')
          if retry_after:
            print("Retrying after", retry_after + 5, "Seconds")
            time.sleep(int(retry_after) + 5)
          else:
            time.sleep(time_interval)
        else:
          time.sleep(time_interval)

    except Exception as e:
      status = f"Exception occurred: {e}"
      print(status)
      retry_count += 1
      print(f"Retrying in {time_interval} seconds... (Retry {retry_count}/{max_retries})")
      time.sleep(time_interval)

  print(f"Max retries reached. Unable to fetch data from {url}.")
  return (status, None)

# %% [markdown]
# # Distribution

# %%
with open('final_packages.txt', "r") as file:
  final_packages = file.read()
final_packages = json.loads(final_packages)

# %%
# put index according to the no. of partitions
idx = 1

# final_packages.txt should have json dump of list of npm package names to be mined
with open('final_packages.txt', "r") as file:
  final_packages = file.read()
final_packages = json.loads(final_packages)

# specify how many parts you want to distribute the mining into
total_parts = 6
i = idx - 1
part_size = len(final_packages) // total_parts
all_packages = final_packages[i * part_size:(i + 1) * part_size if i < total_parts - 1 else len(final_packages)]
print("Total rows to be mined: ", len(all_packages))
# Out:
# Total rows to be mined:  5000

# %%
# create a list of months from May 2018 to January 2024
start_date = datetime(2018, 5, 1)
end_date = datetime(2024, 1, 1)
date_range = pd.date_range(start=start_date, end=end_date, freq='MS')

# %% [markdown]
# # DB Init

# %%
conn = sqlite3.connect(f"download_history_{idx}.db")
cursor = conn.cursor()

column_names = ", ".join(f"m_{month.strftime('%Y%m')} INTEGER" for month in date_range)
sql_query = f"""
        CREATE TABLE IF NOT EXISTS download_data (
            package TEXT,
            {column_names},
            average INTEGER
        )
    """

cursor.execute(sql_query)
conn.commit()

# %%
df = pd.read_sql_query(f"SELECT * FROM download_data", conn)
df
# Out:
# Empty DataFrame
# Columns: [package, m_201805, m_201806, m_201807, m_201808, m_201809, m_201810, m_201811, m_201812, m_201901, m_201902, m_201903, m_201904, m_201905, m_201906, m_201907, m_201908, m_201909, m_201910, m_201911, m_201912, m_202001, m_202002, m_202003, m_202004, m_202005, m_202006, m_202007, m_202008, m_202009, m_202010, m_202011, m_202012, m_202101, m_202102, m_202103, m_202104, m_202105, m_202106, m_202107, m_202108, m_202109, m_202110, m_202111, m_202112, m_202201, m_202202, m_202203, m_202204, m_202205, m_202206, m_202207, m_202208, m_202209, m_202210, m_202211, m_202212, m_202301, m_202302, m_202303, m_202304, m_202305, m_202306, m_202307, m_202308, m_202309, m_202310, m_202311, m_202312, m_202401, average]
# Index: []
#
# [0 rows x 71 columns]

# %% [markdown]
# # Mining

# %%
cursor.execute(f"SELECT * FROM download_data")
rows = cursor.fetchall()
packages_done = [row[0] for row in rows]
package_list = list(set(all_packages) - set(packages_done))
print(f"Rows done so far\t{len(rows)}/{len(all_packages)}")
# Out:
# Rows done so far	0/5000

# %%
scoped_packages = [package for package in package_list if package.startswith('@')]
non_scoped_packages = [package for package in package_list if not package.startswith('@')]
scoped_package_list = [package for package in all_packages if package.startswith('@')]
non_scoped_package_list = [package for package in all_packages if not package.startswith('@')]

print(f"Scoped packages to mine\t\t{len(scoped_packages)}/{len(scoped_package_list)}")
print(f"Non scoped packages to mine\t{len(non_scoped_packages)}/{len(non_scoped_package_list)}")
# Out:
# Scoped packages to mine		1673/1673
# Non scoped packages to mine	3327/3327

# %% [markdown]
# ## Bulk Mining

# %%
# bulk fetch for non-scoped packages
rows_fetched = 0
bulk_batch_size = 128
for i in range(0, len(non_scoped_packages), bulk_batch_size):
  batch = non_scoped_packages[i:i + bulk_batch_size]
  bulk_package_list = ",".join(batch)
  api_call_start_time = time.time()
  total_counts = [None] * bulk_batch_size
  bulk_package_data = {f"m_{month.strftime('%Y%m')}": [None] * bulk_batch_size for month in date_range}

  for month in date_range:
    start_date_str = month.strftime("%Y-%m-%d")
    end_date_str = (month + pd.DateOffset(months=1) - timedelta(days=1)).strftime("%Y-%m-%d")

    bulk_download_api_url = f"https://api.npmjs.org/downloads/point/{start_date_str}:{end_date_str}/{bulk_package_list}"
    (bulk_response_status, bulk_response_data) = fetch_response_without_fail(bulk_download_api_url)

    if bulk_response_status == '200':
      for package_idx in range(len(batch)):
        package = batch[package_idx]
        download_count = GET(bulk_response_data, [package, "downloads"])
        if not download_count == None:
          bulk_package_data[f"m_{month.strftime('%Y%m')}"][package_idx] = download_count

          if total_counts[package_idx] == None:
            total_counts[package_idx] = download_count
          else:
            total_counts[package_idx] += download_count
    else:
      print(f"Failed to fetch data for {bulk_package_list} in {start_date_str}")

  rows_fetched += bulk_batch_size
  api_call_end_time = time.time()
  elapsed_api_call_time = api_call_end_time - api_call_start_time
  print("Rows fetched in " + str(elapsed_api_call_time) + "\tseconds")

  db_update_start_time = time.time()
  for package_idx in range(len(batch)):
    package = batch[package_idx]
    package_data = {"package": package}
    valid_data_len = 0
    for month in date_range:
      package_data[f"m_{month.strftime('%Y%m')}"] = bulk_package_data[f"m_{month.strftime('%Y%m')}"][package_idx]
      if not bulk_package_data[f"m_{month.strftime('%Y%m')}"][package_idx] == None:
        valid_data_len += 1
    package_data["average"] = int(total_counts[package_idx] / valid_data_len) if not total_counts[package_idx] == None else None
    columns = ", ".join(package_data.keys())
    placeholders = ", ".join("?" for _ in package_data)
    sql_query = f"""
        INSERT INTO download_data ({columns})
        VALUES ({placeholders})
    """
    cursor.execute(sql_query, tuple(package_data.values()))
    conn.commit()
  db_update_end_time = time.time()
  elapsed_db_update_time = db_update_end_time - db_update_start_time

  print("==============================================================================")
  print("Database updated in " + str(elapsed_db_update_time) + " seconds")
  print(f"Rows fetched so far: {rows_fetched}/{len(non_scoped_packages)}")
  print("==============================================================================")
  print()
  print()
# Out:
# Rows fetched in 20.14516592025757	seconds
# ==============================================================================
# Database updated in 1.4343268871307373 seconds
# Rows fetched so far: 128/3327
# ==============================================================================
#
#
# Rows fetched in 20.11069631576538	seconds
# ==============================================================================
# Database updated in 1.4965219497680664 seconds
# Rows fetched so far: 256/3327
# ==============================================================================
#
#
# Rows fetched in 20.493934392929077	seconds
# ==============================================================================
# Database updated in 1.5455455780029297 seconds
# Rows fetched so far: 384/3327
# ==============================================================================
#
#
# Rows fetched in 20.57086682319641	seconds
# ==============================================================================
# Database updated in 1.6286582946777344 seconds
# Rows fetched so far: 512/3327
# ==============================================================================
#
#
# Rows fetched in 20.44608426094055	seconds
# ==============================================================================
# Database updated in 1.6562221050262451 seconds
# Rows fetched so far: 640/3327
# ==============================================================================
#
#
# Rows fetched in 20.42780566215515	seconds
# ==============================================================================
# Database updated in 1.717111349105835 seconds
# Rows fetched so far: 768/3327
# ==============================================================================
#
#
# Rows fetched in 20.94654870033264	seconds
# ==============================================================================
# Database updated in 1.7458183765411377 seconds
# Rows fetched so far: 896/3327
# ==============================================================================
#
#
# Rows fetched in 20.71972346305847	seconds
# ==============================================================================
# Database updated in 1.8308556079864502 seconds
# Rows fetched so far: 1024/3327
# ==============================================================================
#
#
# Rows fetched in 20.743690252304077	seconds
# ==============================================================================
# Database updated in 1.8499138355255127 seconds
# Rows fetched so far: 1152/3327
# ==============================================================================
#
#
# Rows fetched in 20.54077386856079	seconds
# ==============================================================================
# Database updated in 1.9082129001617432 seconds
# Rows fetched so far: 1280/3327
# ==============================================================================
#
#
# Rows fetched in 20.73639154434204	seconds
# ==============================================================================
# Database updated in 2.0102860927581787 seconds
# Rows fetched so far: 1408/3327
# ==============================================================================
#
#
# Rows fetched in 21.229098796844482	seconds
# ==============================================================================
# Database updated in 1.9793386459350586 seconds
# Rows fetched so far: 1536/3327
# ==============================================================================
#
#
# Rows fetched in 21.14846968650818	seconds
# ==============================================================================
# Database updated in 2.0113654136657715 seconds
# Rows fetched so far: 1664/3327
# ==============================================================================
#
#
# Rows fetched in 20.910895347595215	seconds
# ==============================================================================
# Database updated in 2.043617010116577 seconds
# Rows fetched so far: 1792/3327
# ==============================================================================
#
#
# Rows fetched in 20.221617221832275	seconds
# ==============================================================================
# Database updated in 2.0967538356781006 seconds
# Rows fetched so far: 1920/3327
# ==============================================================================
#
#
# Rows fetched in 20.5324285030365	seconds
# ==============================================================================
# Database updated in 2.1400725841522217 seconds
# Rows fetched so far: 2048/3327
# ==============================================================================
#
#
# Rows fetched in 19.96604299545288	seconds
# ==============================================================================
# Database updated in 2.242543935775757 seconds
# Rows fetched so far: 2176/3327
# ==============================================================================
#
#
# Rows fetched in 20.229421615600586	seconds
# ==============================================================================
# Database updated in 2.30472993850708 seconds
# Rows fetched so far: 2304/3327
# ==============================================================================
#
#
# Rows fetched in 20.924297332763672	seconds
# ==============================================================================
# Database updated in 2.444537878036499 seconds
# Rows fetched so far: 2432/3327
# ==============================================================================
#
#
# Rows fetched in 20.947925329208374	seconds
# ==============================================================================
# Database updated in 2.3648877143859863 seconds
# Rows fetched so far: 2560/3327
# ==============================================================================
#
#
# Rows fetched in 20.973922967910767	seconds
# ==============================================================================
# Database updated in 2.525023937225342 seconds
# Rows fetched so far: 2688/3327
# ==============================================================================
#
#
# Rows fetched in 20.503853797912598	seconds
# ==============================================================================
# Database updated in 2.931450843811035 seconds
# Rows fetched so far: 2816/3327
# ==============================================================================
#
#
# Rows fetched in 20.101253032684326	seconds
# ==============================================================================
# Database updated in 2.9800567626953125 seconds
# Rows fetched so far: 2944/3327
# ==============================================================================
#
#
# Rows fetched in 20.91650080680847	seconds
# ==============================================================================
# Database updated in 3.318533182144165 seconds
# Rows fetched so far: 3072/3327
# ==============================================================================
#
#
# Rows fetched in 20.543365001678467	seconds
# ==============================================================================
# Database updated in 3.4207003116607666 seconds
# Rows fetched so far: 3200/3327
# ==============================================================================
#
#
# Rows fetched in 19.787978410720825	seconds
# ==============================================================================
# Database updated in 3.384793281555176 seconds
# Rows fetched so far: 3328/3327
# ==============================================================================

# %% [markdown]
# ## Independent mining

# %%
full_date_range = [(date.strftime("%Y-%m-%d"), (date + pd.DateOffset(months=1) - timedelta(days=1)).strftime("%Y-%m-%d")) for date in date_range]

chunk_size = 17
date_range_chunks = [full_date_range[i:i+chunk_size] for i in range(0, len(full_date_range), chunk_size)]
date_range_chunks = [(date_range_chunk[0][0], date_range_chunk[-1][-1]) for date_range_chunk in date_range_chunks]

# %%
rows_fetched = 0
for package in scoped_packages:
  package_data = {"package": package}

  api_call_start_time = time.time()
  for date_range_chunk in date_range_chunks:
    start_date_str = date_range_chunk[0]
    end_date_str = date_range_chunk[1]

    download_api_url = f"https://api.npmjs.org/downloads/range/{start_date_str}:{end_date_str}/{package}"
    (response_status, response_data) = fetch_response_without_fail(download_api_url)

    if response_status == '200':
      download_counts = GET(response_data, "downloads")
      for download_count in download_counts:
        curr_month = download_count['day'][:7]
        curr_downloads = download_count['downloads']
        curr_key = f"m_{curr_month.replace('-', '')}"
        package_data[curr_key] = package_data.get(curr_key, 0) + curr_downloads
    else:
      print(f"Failed to fetch data for {package} in {start_date_str}-{end_date_str}")

  rows_fetched += 1
  api_call_end_time = time.time()
  elapsed_api_call_time = api_call_end_time - api_call_start_time
  print("Rows fetched in " + str(int(elapsed_api_call_time)) + "\tseconds")

  total_count = None
  valid_data_len = 0
  for month in date_range:
    download_count = package_data.get(f"m_{month.strftime('%Y%m')}", None)
    if not download_count == None:
      valid_data_len += 1
      if total_count == None:
        total_count = download_count
      else:
        total_count += download_count
  package_data["average"] = int(total_count / valid_data_len) if not total_count == None else None
  db_update_start_time = time.time()

  columns = ", ".join(package_data.keys())
  placeholders = ", ".join("?" for _ in package_data)
  sql_query = f"""
    INSERT INTO download_data ({columns})
    VALUES ({placeholders})
  """
  cursor.execute(sql_query, tuple(package_data.values()))
  conn.commit()

  db_update_end_time = time.time()
  elapsed_db_update_time = db_update_end_time - db_update_start_time

  db_update_end_time = time.time()
  elapsed_db_update_time = db_update_end_time - db_update_start_time
  print("==============================================================================")
  print("Database updated in " + str(int(elapsed_db_update_time)) + " seconds")
  print(f"Rows fetched so far: {rows_fetched}/{len(scoped_packages)}")
  print("==============================================================================")
  print()
  print()
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# Rows fetched in 1	seconds
# {'package': '@base-framework/atoms', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 0, 'm_202204': 0, 'm_202205': 0, 'm_202206': 0, 'm_202207': 0, 'm_202208': 0, 'm_202209': 0, 'm_202210': 0, 'm_202211': 0, 'm_202212': 0, 'm_202301': 0, 'm_202302': 0, 'm_202303': 0, 'm_202304': 0, 'm_202305': 0, 'm_202306': 0, 'm_202307': 0, 'm_202308': 0, 'm_202309': 0, 'm_202310': 0, 'm_202311': 0, 'm_202312': 122, 'm_202401': 21, 'average': 2}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 891/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@lighting-beetle/lighter-styleguide', 'm_201805': 268, 'm_201806': 51, 'm_201807': 80, 'm_201808': 54, 'm_201809': 17, 'm_201810': 28, 'm_201811': 116, 'm_201812': 115, 'm_201901': 94, 'm_201902': 96, 'm_201903': 140, 'm_201904': 88, 'm_201905': 42, 'm_201906': 125, 'm_201907': 137, 'm_201908': 208, 'm_201909': 155, 'm_201910': 322, 'm_201911': 238, 'm_201912': 123, 'm_202001': 472, 'm_202002': 176, 'm_202003': 425, 'm_202004': 334, 'm_202005': 246, 'm_202006': 169, 'm_202007': 149, 'm_202008': 45, 'm_202009': 46, 'm_202010': 189, 'm_202011': 110, 'm_202012': 147, 'm_202101': 55, 'm_202102': 175, 'm_202103': 436, 'm_202104': 132, 'm_202105': 172, 'm_202106': 112, 'm_202107': 237, 'm_202108': 213, 'm_202109': 111, 'm_202110': 161, 'm_202111': 58, 'm_202112': 113, 'm_202201': 279, 'm_202202': 83, 'm_202203': 226, 'm_202204': 313, 'm_202205': 133, 'm_202206': 33, 'm_202207': 167, 'm_202208': 500, 'm_202209': 284, 'm_202210': 154, 'm_202211': 246, 'm_202212': 173, 'm_202301': 165, 'm_202302': 108, 'm_202303': 198, 'm_202304': 168, 'm_202305': 169, 'm_202306': 104, 'm_202307': 72, 'm_202308': 174, 'm_202309': 292, 'm_202310': 667, 'm_202311': 61, 'm_202312': 77, 'm_202401': 98, 'average': 172}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 892/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@waweb/base-ui.text.heading', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 629, 'm_202107': 208, 'm_202108': 78, 'm_202109': 96, 'm_202110': 6, 'm_202111': 18, 'm_202112': 32, 'm_202201': 125, 'm_202202': 347, 'm_202203': 50, 'm_202204': 418, 'm_202205': 233, 'm_202206': 103, 'm_202207': 31, 'm_202208': 153, 'm_202209': 81, 'm_202210': 44, 'm_202211': 32, 'm_202212': 88, 'm_202301': 49, 'm_202302': 37, 'm_202303': 60, 'm_202304': 43, 'm_202305': 6, 'm_202306': 10, 'm_202307': 58, 'm_202308': 44, 'm_202309': 19, 'm_202310': 231, 'm_202311': 23, 'm_202312': 26, 'm_202401': 27, 'average': 49}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 893/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@tylergaffaney/eslint-config-vue', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 0, 'm_202204': 0, 'm_202205': 0, 'm_202206': 0, 'm_202207': 0, 'm_202208': 0, 'm_202209': 0, 'm_202210': 0, 'm_202211': 0, 'm_202212': 0, 'm_202301': 0, 'm_202302': 424, 'm_202303': 56, 'm_202304': 22, 'm_202305': 13, 'm_202306': 8, 'm_202307': 21, 'm_202308': 19, 'm_202309': 5, 'm_202310': 65, 'm_202311': 12, 'm_202312': 1, 'm_202401': 6, 'average': 9}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 894/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@talixo/combo-box', 'm_201805': 502, 'm_201806': 113, 'm_201807': 311, 'm_201808': 285, 'm_201809': 26, 'm_201810': 260, 'm_201811': 624, 'm_201812': 620, 'm_201901': 630, 'm_201902': 433, 'm_201903': 499, 'm_201904': 538, 'm_201905': 688, 'm_201906': 691, 'm_201907': 1342, 'm_201908': 1109, 'm_201909': 198, 'm_201910': 57, 'm_201911': 72, 'm_201912': 89, 'm_202001': 173, 'm_202002': 23, 'm_202003': 58, 'm_202004': 23, 'm_202005': 38, 'm_202006': 40, 'm_202007': 60, 'm_202008': 40, 'm_202009': 101, 'm_202010': 180, 'm_202011': 145, 'm_202012': 103, 'm_202101': 120, 'm_202102': 97, 'm_202103': 95, 'm_202104': 79, 'm_202105': 72, 'm_202106': 81, 'm_202107': 120, 'm_202108': 72, 'm_202109': 72, 'm_202110': 62, 'm_202111': 40, 'm_202112': 37, 'm_202201': 49, 'm_202202': 90, 'm_202203': 57, 'm_202204': 94, 'm_202205': 75, 'm_202206': 41, 'm_202207': 40, 'm_202208': 115, 'm_202209': 107, 'm_202210': 50, 'm_202211': 32, 'm_202212': 32, 'm_202301': 52, 'm_202302': 33, 'm_202303': 86, 'm_202304': 42, 'm_202305': 384, 'm_202306': 114, 'm_202307': 72, 'm_202308': 281, 'm_202309': 506, 'm_202310': 964, 'm_202311': 460, 'm_202312': 402, 'm_202401': 463, 'average': 226}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 895/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@gr4vy/poutine-react', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 370, 'm_202202': 227, 'm_202203': 386, 'm_202204': 387, 'm_202205': 1153, 'm_202206': 970, 'm_202207': 1626, 'm_202208': 1997, 'm_202209': 1570, 'm_202210': 2444, 'm_202211': 1747, 'm_202212': 1028, 'm_202301': 1252, 'm_202302': 643, 'm_202303': 1863, 'm_202304': 1121, 'm_202305': 1380, 'm_202306': 863, 'm_202307': 1484, 'm_202308': 813, 'm_202309': 1431, 'm_202310': 2439, 'm_202311': 1164, 'm_202312': 719, 'm_202401': 1608, 'average': 444}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 896/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@mlaopane/rxhr', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 47, 'm_201909': 8, 'm_201910': 9, 'm_201911': 17, 'm_201912': 6, 'm_202001': 9, 'm_202002': 9, 'm_202003': 13, 'm_202004': 3, 'm_202005': 6, 'm_202006': 9, 'm_202007': 11, 'm_202008': 21, 'm_202009': 7, 'm_202010': 11, 'm_202011': 7, 'm_202012': 2, 'm_202101': 3, 'm_202102': 4, 'm_202103': 17, 'm_202104': 5, 'm_202105': 8, 'm_202106': 25, 'm_202107': 27, 'm_202108': 8, 'm_202109': 9, 'm_202110': 11, 'm_202111': 4, 'm_202112': 7, 'm_202201': 9, 'm_202202': 12, 'm_202203': 8, 'm_202204': 22, 'm_202205': 12, 'm_202206': 2, 'm_202207': 5, 'm_202208': 15, 'm_202209': 15, 'm_202210': 7, 'm_202211': 7, 'm_202212': 7, 'm_202301': 9, 'm_202302': 6, 'm_202303': 6, 'm_202304': 7, 'm_202305': 2, 'm_202306': 11, 'm_202307': 10, 'm_202308': 28, 'm_202309': 7, 'm_202310': 31, 'm_202311': 9, 'm_202312': 5, 'm_202401': 3, 'average': 8}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 897/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@dreamsicle.io/create-component', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 0, 'm_202204': 0, 'm_202205': 309, 'm_202206': 30, 'm_202207': 35, 'm_202208': 106, 'm_202209': 66, 'm_202210': 25, 'm_202211': 20, 'm_202212': 26, 'm_202301': 23, 'm_202302': 34, 'm_202303': 120, 'm_202304': 34, 'm_202305': 14, 'm_202306': 39, 'm_202307': 37, 'm_202308': 17, 'm_202309': 39, 'm_202310': 125, 'm_202311': 26, 'm_202312': 20, 'm_202401': 21, 'average': 16}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 898/1673
# ==============================================================================
#
#
# Error: 404, skipping url https://api.npmjs.org/downloads/range/2018-05-01:2019-09-30/@zalastax/nolb-dbg
# Failed to fetch data for @zalastax/nolb-dbg in 2018-05-01-2019-09-30
# Error: 404, skipping url https://api.npmjs.org/downloads/range/2019-10-01:2021-02-28/@zalastax/nolb-dbg
# Failed to fetch data for @zalastax/nolb-dbg in 2019-10-01-2021-02-28
# Error: 404, skipping url https://api.npmjs.org/downloads/range/2021-03-01:2022-07-31/@zalastax/nolb-dbg
# Failed to fetch data for @zalastax/nolb-dbg in 2021-03-01-2022-07-31
# Error: 404, skipping url https://api.npmjs.org/downloads/range/2022-08-01:2023-12-31/@zalastax/nolb-dbg
# Failed to fetch data for @zalastax/nolb-dbg in 2022-08-01-2023-12-31
# Error: 404, skipping url https://api.npmjs.org/downloads/range/2024-01-01:2024-01-31/@zalastax/nolb-dbg
# Failed to fetch data for @zalastax/nolb-dbg in 2024-01-01-2024-01-31
# Rows fetched in 1	seconds
# {'package': '@zalastax/nolb-dbg', 'average': None}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 899/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@equinor/fusion-react-date', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 44, 'm_202109': 220, 'm_202110': 399, 'm_202111': 305, 'm_202112': 134, 'm_202201': 98, 'm_202202': 171, 'm_202203': 111, 'm_202204': 258, 'm_202205': 66, 'm_202206': 289, 'm_202207': 295, 'm_202208': 398, 'm_202209': 279, 'm_202210': 133, 'm_202211': 228, 'm_202212': 172, 'm_202301': 199, 'm_202302': 146, 'm_202303': 239, 'm_202304': 279, 'm_202305': 123, 'm_202306': 537, 'm_202307': 571, 'm_202308': 196, 'm_202309': 342, 'm_202310': 667, 'm_202311': 209, 'm_202312': 222, 'm_202401': 223, 'average': 109}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 900/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@anchan828/nest-bull', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 783, 'm_201901': 223, 'm_201902': 76, 'm_201903': 351, 'm_201904': 437, 'm_201905': 544, 'm_201906': 1412, 'm_201907': 3037, 'm_201908': 3234, 'm_201909': 3344, 'm_201910': 3390, 'm_201911': 2400, 'm_201912': 1804, 'm_202001': 1939, 'm_202002': 771, 'm_202003': 829, 'm_202004': 1009, 'm_202005': 553, 'm_202006': 415, 'm_202007': 442, 'm_202008': 672, 'm_202009': 998, 'm_202010': 1031, 'm_202011': 969, 'm_202012': 1144, 'm_202101': 1131, 'm_202102': 1125, 'm_202103': 2139, 'm_202104': 621, 'm_202105': 1310, 'm_202106': 627, 'm_202107': 1573, 'm_202108': 809, 'm_202109': 1228, 'm_202110': 578, 'm_202111': 2005, 'm_202112': 1182, 'm_202201': 1525, 'm_202202': 1028, 'm_202203': 1534, 'm_202204': 2187, 'm_202205': 1092, 'm_202206': 680, 'm_202207': 1901, 'm_202208': 1844, 'm_202209': 2043, 'm_202210': 1830, 'm_202211': 788, 'm_202212': 847, 'm_202301': 1753, 'm_202302': 1925, 'm_202303': 2257, 'm_202304': 1320, 'm_202305': 1589, 'm_202306': 2097, 'm_202307': 3180, 'm_202308': 2811, 'm_202309': 7280, 'm_202310': 4827, 'm_202311': 2779, 'm_202312': 1751, 'm_202401': 1356, 'average': 1425}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 901/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@alifd/theme-20264', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 51, 'm_202112': 8, 'm_202201': 14, 'm_202202': 6, 'm_202203': 13, 'm_202204': 14, 'm_202205': 10, 'm_202206': 4, 'm_202207': 8, 'm_202208': 8, 'm_202209': 10, 'm_202210': 6, 'm_202211': 7, 'm_202212': 9, 'm_202301': 29, 'm_202302': 24, 'm_202303': 22, 'm_202304': 17, 'm_202305': 5, 'm_202306': 5, 'm_202307': 7, 'm_202308': 10, 'm_202309': 40, 'm_202310': 25, 'm_202311': 8, 'm_202312': 5, 'm_202401': 7, 'average': 5}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 902/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@qxy/stylelint-config', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 171, 'm_202102': 23, 'm_202103': 180, 'm_202104': 25, 'm_202105': 102, 'm_202106': 45, 'm_202107': 82, 'm_202108': 25, 'm_202109': 84, 'm_202110': 16, 'm_202111': 127, 'm_202112': 83, 'm_202201': 47, 'm_202202': 79, 'm_202203': 40, 'm_202204': 67, 'm_202205': 55, 'm_202206': 36, 'm_202207': 288, 'm_202208': 201, 'm_202209': 210, 'm_202210': 330, 'm_202211': 339, 'm_202212': 146, 'm_202301': 127, 'm_202302': 223, 'm_202303': 372, 'm_202304': 400, 'm_202305': 477, 'm_202306': 70, 'm_202307': 419, 'm_202308': 372, 'm_202309': 352, 'm_202310': 640, 'm_202311': 405, 'm_202312': 113, 'm_202401': 344, 'average': 103}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 903/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@types/time-span', 'm_201805': 536, 'm_201806': 794, 'm_201807': 685, 'm_201808': 636, 'm_201809': 546, 'm_201810': 1025, 'm_201811': 3164, 'm_201812': 2386, 'm_201901': 2026, 'm_201902': 2460, 'm_201903': 1286, 'm_201904': 103, 'm_201905': 383, 'm_201906': 163, 'm_201907': 214, 'm_201908': 146, 'm_201909': 74, 'm_201910': 142, 'm_201911': 433, 'm_201912': 526, 'm_202001': 639, 'm_202002': 711, 'm_202003': 980, 'm_202004': 1173, 'm_202005': 926, 'm_202006': 542, 'm_202007': 387, 'm_202008': 117, 'm_202009': 146, 'm_202010': 228, 'm_202011': 265, 'm_202012': 260, 'm_202101': 153, 'm_202102': 237, 'm_202103': 209, 'm_202104': 159, 'm_202105': 51, 'm_202106': 159, 'm_202107': 89, 'm_202108': 34, 'm_202109': 48, 'm_202110': 99, 'm_202111': 39, 'm_202112': 196, 'm_202201': 216, 'm_202202': 278, 'm_202203': 252, 'm_202204': 220, 'm_202205': 169, 'm_202206': 173, 'm_202207': 153, 'm_202208': 91, 'm_202209': 80, 'm_202210': 114, 'm_202211': 72, 'm_202212': 110, 'm_202301': 167, 'm_202302': 138, 'm_202303': 45, 'm_202304': 46, 'm_202305': 39, 'm_202306': 97, 'm_202307': 41, 'm_202308': 60, 'm_202309': 90, 'm_202310': 94, 'm_202311': 85, 'm_202312': 42, 'm_202401': 61, 'average': 413}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 904/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@meenjs/static', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 895, 'm_202007': 679, 'm_202008': 489, 'm_202009': 715, 'm_202010': 541, 'm_202011': 243, 'm_202012': 330, 'm_202101': 80, 'm_202102': 183, 'm_202103': 218, 'm_202104': 125, 'm_202105': 79, 'm_202106': 134, 'm_202107': 182, 'm_202108': 385, 'm_202109': 188, 'm_202110': 27, 'm_202111': 56, 'm_202112': 123, 'm_202201': 213, 'm_202202': 60, 'm_202203': 167, 'm_202204': 274, 'm_202205': 164, 'm_202206': 59, 'm_202207': 107, 'm_202208': 414, 'm_202209': 245, 'm_202210': 165, 'm_202211': 162, 'm_202212': 20, 'm_202301': 120, 'm_202302': 76, 'm_202303': 119, 'm_202304': 67, 'm_202305': 93, 'm_202306': 57, 'm_202307': 117, 'm_202308': 59, 'm_202309': 158, 'm_202310': 704, 'm_202311': 55, 'm_202312': 74, 'm_202401': 121, 'average': 138}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 905/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@reified/ecma262', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 0, 'm_202204': 0, 'm_202205': 0, 'm_202206': 0, 'm_202207': 0, 'm_202208': 0, 'm_202209': 0, 'm_202210': 0, 'm_202211': 0, 'm_202212': 89, 'm_202301': 5, 'm_202302': 6, 'm_202303': 7, 'm_202304': 4, 'm_202305': 5, 'm_202306': 3, 'm_202307': 8, 'm_202308': 3, 'm_202309': 3, 'm_202310': 19, 'm_202311': 4, 'm_202312': 6, 'm_202401': 3, 'average': 2}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 906/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@wasc/wildduck-sdk', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 206, 'm_202203': 21, 'm_202204': 42, 'm_202205': 28, 'm_202206': 3, 'm_202207': 65, 'm_202208': 27, 'm_202209': 23, 'm_202210': 17, 'm_202211': 7, 'm_202212': 13, 'm_202301': 15, 'm_202302': 16, 'm_202303': 18, 'm_202304': 8, 'm_202305': 3, 'm_202306': 11, 'm_202307': 19, 'm_202308': 17, 'm_202309': 5, 'm_202310': 57, 'm_202311': 8, 'm_202312': 10, 'm_202401': 7, 'average': 9}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 907/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@osui/tag', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 42, 'm_202009': 250, 'm_202010': 273, 'm_202011': 257, 'm_202012': 262, 'm_202101': 290, 'm_202102': 166, 'm_202103': 266, 'm_202104': 224, 'm_202105': 224, 'm_202106': 262, 'm_202107': 274, 'm_202108': 252, 'm_202109': 405, 'm_202110': 127, 'm_202111': 371, 'm_202112': 206, 'm_202201': 337, 'm_202202': 205, 'm_202203': 388, 'm_202204': 458, 'm_202205': 390, 'm_202206': 282, 'm_202207': 480, 'm_202208': 420, 'm_202209': 447, 'm_202210': 229, 'm_202211': 199, 'm_202212': 262, 'm_202301': 262, 'm_202302': 257, 'm_202303': 369, 'm_202304': 391, 'm_202305': 594, 'm_202306': 305, 'm_202307': 333, 'm_202308': 303, 'm_202309': 424, 'm_202310': 926, 'm_202311': 220, 'm_202312': 231, 'm_202401': 577, 'average': 194}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 908/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@nocturnaljs/schema', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 34, 'm_202110': 9, 'm_202111': 6, 'm_202112': 6, 'm_202201': 9, 'm_202202': 6, 'm_202203': 4, 'm_202204': 16, 'm_202205': 13, 'm_202206': 5, 'm_202207': 5, 'm_202208': 11, 'm_202209': 13, 'm_202210': 13, 'm_202211': 6, 'm_202212': 2, 'm_202301': 7, 'm_202302': 9, 'm_202303': 5, 'm_202304': 6, 'm_202305': 2, 'm_202306': 7, 'm_202307': 7, 'm_202308': 23, 'm_202309': 3, 'm_202310': 20, 'm_202311': 6, 'm_202312': 2, 'm_202401': 3, 'average': 3}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 909/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@wqy445/canvasboard', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 99, 'm_202108': 59, 'm_202109': 23, 'm_202110': 4, 'm_202111': 9, 'm_202112': 11, 'm_202201': 8, 'm_202202': 8, 'm_202203': 10, 'm_202204': 34, 'm_202205': 16, 'm_202206': 6, 'm_202207': 12, 'm_202208': 21, 'm_202209': 18, 'm_202210': 11, 'm_202211': 6, 'm_202212': 10, 'm_202301': 10, 'm_202302': 9, 'm_202303': 13, 'm_202304': 11, 'm_202305': 2, 'm_202306': 6, 'm_202307': 13, 'm_202308': 8, 'm_202309': 6, 'm_202310': 43, 'm_202311': 10, 'm_202312': 5, 'm_202401': 6, 'average': 7}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 910/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@chaff/drowsy-client', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 6, 'm_201906': 18, 'm_201907': 29, 'm_201908': 11, 'm_201909': 10, 'm_201910': 13, 'm_201911': 10, 'm_201912': 21, 'm_202001': 7, 'm_202002': 7, 'm_202003': 9, 'm_202004': 3, 'm_202005': 7, 'm_202006': 4, 'm_202007': 6, 'm_202008': 2, 'm_202009': 6, 'm_202010': 4, 'm_202011': 25, 'm_202012': 4, 'm_202101': 5, 'm_202102': 1, 'm_202103': 28, 'm_202104': 3, 'm_202105': 4, 'm_202106': 21, 'm_202107': 27, 'm_202108': 8, 'm_202109': 9, 'm_202110': 6, 'm_202111': 9, 'm_202112': 8, 'm_202201': 10, 'm_202202': 5, 'm_202203': 17, 'm_202204': 19, 'm_202205': 12, 'm_202206': 8, 'm_202207': 8, 'm_202208': 8, 'm_202209': 13, 'm_202210': 8, 'm_202211': 12, 'm_202212': 1, 'm_202301': 17, 'm_202302': 7, 'm_202303': 6, 'm_202304': 6, 'm_202305': 2, 'm_202306': 7, 'm_202307': 8, 'm_202308': 4, 'm_202309': 18, 'm_202310': 23, 'm_202311': 11, 'm_202312': 14, 'm_202401': 11, 'average': 8}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 911/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@fontsource/lexend-deca', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 110, 'm_202101': 35, 'm_202102': 208, 'm_202103': 223, 'm_202104': 186, 'm_202105': 264, 'm_202106': 226, 'm_202107': 196, 'm_202108': 249, 'm_202109': 248, 'm_202110': 95, 'm_202111': 310, 'm_202112': 321, 'm_202201': 690, 'm_202202': 565, 'm_202203': 505, 'm_202204': 716, 'm_202205': 503, 'm_202206': 1387, 'm_202207': 1096, 'm_202208': 1267, 'm_202209': 1343, 'm_202210': 1623, 'm_202211': 1928, 'm_202212': 991, 'm_202301': 2008, 'm_202302': 2147, 'm_202303': 2123, 'm_202304': 1520, 'm_202305': 1795, 'm_202306': 1662, 'm_202307': 2078, 'm_202308': 2522, 'm_202309': 2283, 'm_202310': 2665, 'm_202311': 2196, 'm_202312': 1383, 'm_202401': 3172, 'average': 620}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 912/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@multer/s3', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 0, 'm_202204': 0, 'm_202205': 178, 'm_202206': 341, 'm_202207': 272, 'm_202208': 424, 'm_202209': 261, 'm_202210': 94, 'm_202211': 177, 'm_202212': 36, 'm_202301': 66, 'm_202302': 24, 'm_202303': 35, 'm_202304': 36, 'm_202305': 10, 'm_202306': 54, 'm_202307': 22, 'm_202308': 10, 'm_202309': 15, 'm_202310': 57, 'm_202311': 14, 'm_202312': 4, 'm_202401': 8, 'average': 30}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 913/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@ew-did-registry/did-store-interface', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 46, 'm_202005': 14, 'm_202006': 5, 'm_202007': 7, 'm_202008': 5, 'm_202009': 103, 'm_202010': 57, 'm_202011': 240, 'm_202012': 257, 'm_202101': 353, 'm_202102': 333, 'm_202103': 1244, 'm_202104': 527, 'm_202105': 276, 'm_202106': 605, 'm_202107': 703, 'm_202108': 1158, 'm_202109': 1434, 'm_202110': 1476, 'm_202111': 1610, 'm_202112': 2739, 'm_202201': 2216, 'm_202202': 1901, 'm_202203': 2127, 'm_202204': 2069, 'm_202205': 1830, 'm_202206': 2306, 'm_202207': 2079, 'm_202208': 2835, 'm_202209': 2283, 'm_202210': 3364, 'm_202211': 2321, 'm_202212': 2606, 'm_202301': 2995, 'm_202302': 2698, 'm_202303': 2669, 'm_202304': 1819, 'm_202305': 1402, 'm_202306': 2293, 'm_202307': 2528, 'm_202308': 2681, 'm_202309': 1808, 'm_202310': 2675, 'm_202311': 1496, 'm_202312': 697, 'm_202401': 685, 'average': 979}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 914/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@bullhorn/connect', 'm_201805': 38, 'm_201806': 7, 'm_201807': 16, 'm_201808': 27, 'm_201809': 5, 'm_201810': 7, 'm_201811': 36, 'm_201812': 32, 'm_201901': 17, 'm_201902': 10, 'm_201903': 15, 'm_201904': 34, 'm_201905': 12, 'm_201906': 43, 'm_201907': 55, 'm_201908': 19, 'm_201909': 20, 'm_201910': 23, 'm_201911': 33, 'm_201912': 54, 'm_202001': 36, 'm_202002': 20, 'm_202003': 8, 'm_202004': 2, 'm_202005': 41, 'm_202006': 15, 'm_202007': 5, 'm_202008': 7, 'm_202009': 17, 'm_202010': 19, 'm_202011': 59, 'm_202012': 92, 'm_202101': 27, 'm_202102': 4, 'm_202103': 48, 'm_202104': 23, 'm_202105': 22, 'm_202106': 29, 'm_202107': 71, 'm_202108': 116, 'm_202109': 67, 'm_202110': 65, 'm_202111': 35, 'm_202112': 26, 'm_202201': 42, 'm_202202': 19, 'm_202203': 74, 'm_202204': 101, 'm_202205': 49, 'm_202206': 15, 'm_202207': 75, 'm_202208': 67, 'm_202209': 45, 'm_202210': 51, 'm_202211': 25, 'm_202212': 27, 'm_202301': 60, 'm_202302': 9, 'm_202303': 46, 'm_202304': 31, 'm_202305': 28, 'm_202306': 28, 'm_202307': 26, 'm_202308': 40, 'm_202309': 166, 'm_202310': 141, 'm_202311': 74, 'm_202312': 6, 'm_202401': 17, 'average': 37}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 915/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@uranashel/youtubesearch', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 0, 'm_202204': 0, 'm_202205': 0, 'm_202206': 0, 'm_202207': 0, 'm_202208': 0, 'm_202209': 4, 'm_202210': 43, 'm_202211': 23, 'm_202212': 27, 'm_202301': 41, 'm_202302': 10, 'm_202303': 25, 'm_202304': 17, 'm_202305': 11, 'm_202306': 21, 'm_202307': 22, 'm_202308': 5, 'm_202309': 5, 'm_202310': 58, 'm_202311': 9, 'm_202312': 13, 'm_202401': 9, 'average': 4}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 916/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@endlessjs/security', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 624, 'm_201911': 176, 'm_201912': 28, 'm_202001': 103, 'm_202002': 50, 'm_202003': 12, 'm_202004': 12, 'm_202005': 6, 'm_202006': 28, 'm_202007': 4, 'm_202008': 4, 'm_202009': 47, 'm_202010': 78, 'm_202011': 58, 'm_202012': 11, 'm_202101': 29, 'm_202102': 23, 'm_202103': 72, 'm_202104': 54, 'm_202105': 67, 'm_202106': 44, 'm_202107': 66, 'm_202108': 140, 'm_202109': 95, 'm_202110': 4, 'm_202111': 57, 'm_202112': 26, 'm_202201': 68, 'm_202202': 7, 'm_202203': 136, 'm_202204': 118, 'm_202205': 56, 'm_202206': 28, 'm_202207': 46, 'm_202208': 147, 'm_202209': 114, 'm_202210': 144, 'm_202211': 34, 'm_202212': 8, 'm_202301': 60, 'm_202302': 42, 'm_202303': 81, 'm_202304': 42, 'm_202305': 39, 'm_202306': 17, 'm_202307': 52, 'm_202308': 48, 'm_202309': 72, 'm_202310': 307, 'm_202311': 54, 'm_202312': 25, 'm_202401': 55, 'average': 53}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 917/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@lengoo/file-manager', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 82, 'm_201906': 45, 'm_201907': 52, 'm_201908': 14, 'm_201909': 33, 'm_201910': 32, 'm_201911': 73, 'm_201912': 20, 'm_202001': 79, 'm_202002': 31, 'm_202003': 57, 'm_202004': 38, 'm_202005': 34, 'm_202006': 15, 'm_202007': 62, 'm_202008': 65, 'm_202009': 40, 'm_202010': 54, 'm_202011': 56, 'm_202012': 18, 'm_202101': 19, 'm_202102': 25, 'm_202103': 51, 'm_202104': 49, 'm_202105': 35, 'm_202106': 38, 'm_202107': 52, 'm_202108': 44, 'm_202109': 21, 'm_202110': 3, 'm_202111': 3, 'm_202112': 19, 'm_202201': 17, 'm_202202': 22, 'm_202203': 24, 'm_202204': 34, 'm_202205': 24, 'm_202206': 2, 'm_202207': 11, 'm_202208': 35, 'm_202209': 30, 'm_202210': 16, 'm_202211': 8, 'm_202212': 16, 'm_202301': 17, 'm_202302': 9, 'm_202303': 15, 'm_202304': 8, 'm_202305': 3, 'm_202306': 11, 'm_202307': 17, 'm_202308': 44, 'm_202309': 20, 'm_202310': 68, 'm_202311': 15, 'm_202312': 7, 'm_202401': 7, 'average': 25}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 918/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@dvkiin/material-commons', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 73, 'm_201908': 349, 'm_201909': 85, 'm_201910': 314, 'm_201911': 238, 'm_201912': 193, 'm_202001': 136, 'm_202002': 116, 'm_202003': 199, 'm_202004': 66, 'm_202005': 185, 'm_202006': 300, 'm_202007': 320, 'm_202008': 55, 'm_202009': 127, 'm_202010': 175, 'm_202011': 293, 'm_202012': 183, 'm_202101': 127, 'm_202102': 80, 'm_202103': 490, 'm_202104': 158, 'm_202105': 109, 'm_202106': 113, 'm_202107': 170, 'm_202108': 132, 'm_202109': 164, 'm_202110': 48, 'm_202111': 83, 'm_202112': 43, 'm_202201': 125, 'm_202202': 102, 'm_202203': 115, 'm_202204': 148, 'm_202205': 78, 'm_202206': 37, 'm_202207': 69, 'm_202208': 172, 'm_202209': 178, 'm_202210': 107, 'm_202211': 37, 'm_202212': 55, 'm_202301': 89, 'm_202302': 68, 'm_202303': 123, 'm_202304': 44, 'm_202305': 33, 'm_202306': 37, 'm_202307': 89, 'm_202308': 38, 'm_202309': 139, 'm_202310': 454, 'm_202311': 79, 'm_202312': 4, 'm_202401': 47, 'average': 110}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 919/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@lucario/cordova-plugin-browsertab', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 17, 'm_202009': 12, 'm_202010': 14, 'm_202011': 11, 'm_202012': 8, 'm_202101': 4, 'm_202102': 107, 'm_202103': 40, 'm_202104': 9, 'm_202105': 17, 'm_202106': 47, 'm_202107': 31, 'm_202108': 106, 'm_202109': 369, 'm_202110': 163, 'm_202111': 19, 'm_202112': 58, 'm_202201': 74, 'm_202202': 42, 'm_202203': 40, 'm_202204': 31, 'm_202205': 39, 'm_202206': 190, 'm_202207': 156, 'm_202208': 71, 'm_202209': 48, 'm_202210': 27, 'm_202211': 90, 'm_202212': 106, 'm_202301': 20, 'm_202302': 31, 'm_202303': 91, 'm_202304': 43, 'm_202305': 112, 'm_202306': 98, 'm_202307': 59, 'm_202308': 40, 'm_202309': 37, 'm_202310': 73, 'm_202311': 110, 'm_202312': 49, 'm_202401': 114, 'average': 40}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 920/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@xyo-network/react-table', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 0, 'm_202204': 0, 'm_202205': 0, 'm_202206': 0, 'm_202207': 0, 'm_202208': 0, 'm_202209': 898, 'm_202210': 3734, 'm_202211': 3896, 'm_202212': 2393, 'm_202301': 2531, 'm_202302': 3930, 'm_202303': 11862, 'm_202304': 4382, 'm_202305': 6159, 'm_202306': 5233, 'm_202307': 10624, 'm_202308': 6210, 'm_202309': 4533, 'm_202310': 11857, 'm_202311': 3546, 'm_202312': 3363, 'm_202401': 5542, 'average': 1314}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 921/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@gaoding/apollo-client', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 19, 'm_201907': 18, 'm_201908': 11, 'm_201909': 3, 'm_201910': 12, 'm_201911': 11, 'm_201912': 3, 'm_202001': 7, 'm_202002': 140, 'm_202003': 12, 'm_202004': 7, 'm_202005': 6, 'm_202006': 13, 'm_202007': 12, 'm_202008': 2, 'm_202009': 13, 'm_202010': 20, 'm_202011': 32, 'm_202012': 37, 'm_202101': 4, 'm_202102': 160, 'm_202103': 223, 'm_202104': 131, 'm_202105': 172, 'm_202106': 181, 'm_202107': 184, 'm_202108': 107, 'm_202109': 84, 'm_202110': 32, 'm_202111': 62, 'm_202112': 40, 'm_202201': 83, 'm_202202': 63, 'm_202203': 114, 'm_202204': 68, 'm_202205': 51, 'm_202206': 42, 'm_202207': 36, 'm_202208': 104, 'm_202209': 79, 'm_202210': 289, 'm_202211': 156, 'm_202212': 291, 'm_202301': 148, 'm_202302': 128, 'm_202303': 206, 'm_202304': 222, 'm_202305': 58, 'm_202306': 15, 'm_202307': 289, 'm_202308': 184, 'm_202309': 188, 'm_202310': 325, 'm_202311': 152, 'm_202312': 132, 'm_202401': 116, 'average': 76}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 922/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@esy-cross/conf', 'm_201805': 13, 'm_201806': 5, 'm_201807': 13, 'm_201808': 17, 'm_201809': 4, 'm_201810': 7, 'm_201811': 14, 'm_201812': 24, 'm_201901': 17, 'm_201902': 4, 'm_201903': 8, 'm_201904': 8, 'm_201905': 9, 'm_201906': 16, 'm_201907': 19, 'm_201908': 13, 'm_201909': 6, 'm_201910': 7, 'm_201911': 9, 'm_201912': 5, 'm_202001': 15, 'm_202002': 7, 'm_202003': 7, 'm_202004': 1, 'm_202005': 7, 'm_202006': 8, 'm_202007': 4, 'm_202008': 3, 'm_202009': 15, 'm_202010': 13, 'm_202011': 33, 'm_202012': 7, 'm_202101': 4, 'm_202102': 13, 'm_202103': 35, 'm_202104': 18, 'm_202105': 10, 'm_202106': 23, 'm_202107': 34, 'm_202108': 12, 'm_202109': 12, 'm_202110': 6, 'm_202111': 7, 'm_202112': 4, 'm_202201': 9, 'm_202202': 14, 'm_202203': 9, 'm_202204': 21, 'm_202205': 13, 'm_202206': 5, 'm_202207': 8, 'm_202208': 22, 'm_202209': 21, 'm_202210': 8, 'm_202211': 6, 'm_202212': 7, 'm_202301': 12, 'm_202302': 5, 'm_202303': 8, 'm_202304': 7, 'm_202305': 3, 'm_202306': 9, 'm_202307': 6, 'm_202308': 5, 'm_202309': 10, 'm_202310': 33, 'm_202311': 11, 'm_202312': 3, 'm_202401': 9, 'average': 11}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 923/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@hyper.fun/material-icon-accessible-forward-filled', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 0, 'm_202204': 0, 'm_202205': 0, 'm_202206': 0, 'm_202207': 45, 'm_202208': 64, 'm_202209': 27, 'm_202210': 7, 'm_202211': 4, 'm_202212': 7, 'm_202301': 72, 'm_202302': 12, 'm_202303': 6, 'm_202304': 10, 'm_202305': 3, 'm_202306': 5, 'm_202307': 10, 'm_202308': 5, 'm_202309': 9, 'm_202310': 31, 'm_202311': 12, 'm_202312': 13, 'm_202401': 3, 'average': 5}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 924/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# ...
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 1495/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@cosmjss/crypto', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 0, 'm_202204': 0, 'm_202205': 0, 'm_202206': 0, 'm_202207': 0, 'm_202208': 0, 'm_202209': 0, 'm_202210': 0, 'm_202211': 0, 'm_202212': 0, 'm_202301': 0, 'm_202302': 0, 'm_202303': 0, 'm_202304': 0, 'm_202305': 0, 'm_202306': 0, 'm_202307': 0, 'm_202308': 0, 'm_202309': 0, 'm_202310': 0, 'm_202311': 0, 'm_202312': 0, 'm_202401': 359, 'average': 5}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 1496/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@xobj/buffer', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 0, 'm_202204': 494, 'm_202205': 123, 'm_202206': 46, 'm_202207': 26, 'm_202208': 92, 'm_202209': 69, 'm_202210': 38, 'm_202211': 12, 'm_202212': 42, 'm_202301': 697, 'm_202302': 181, 'm_202303': 144, 'm_202304': 55, 'm_202305': 39, 'm_202306': 46, 'm_202307': 60, 'm_202308': 42, 'm_202309': 21, 'm_202310': 243, 'm_202311': 606, 'm_202312': 26, 'm_202401': 27, 'average': 45}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 1497/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@aurodesignsystem/auro-tracer', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 70, 'm_202104': 9, 'm_202105': 8, 'm_202106': 23, 'm_202107': 25, 'm_202108': 8, 'm_202109': 17, 'm_202110': 5, 'm_202111': 14, 'm_202112': 7, 'm_202201': 11, 'm_202202': 8, 'm_202203': 12, 'm_202204': 16, 'm_202205': 9, 'm_202206': 5, 'm_202207': 8, 'm_202208': 12, 'm_202209': 15, 'm_202210': 7, 'm_202211': 8, 'm_202212': 4, 'm_202301': 10, 'm_202302': 18, 'm_202303': 10, 'm_202304': 12, 'm_202305': 9, 'm_202306': 14, 'm_202307': 10, 'm_202308': 23, 'm_202309': 26, 'm_202310': 22, 'm_202311': 8, 'm_202312': 5, 'm_202401': 18, 'average': 7}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 1498/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@tnshopping/common', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 0, 'm_202204': 0, 'm_202205': 0, 'm_202206': 135, 'm_202207': 16, 'm_202208': 144, 'm_202209': 21, 'm_202210': 11, 'm_202211': 10, 'm_202212': 10, 'm_202301': 4, 'm_202302': 8, 'm_202303': 12, 'm_202304': 9, 'm_202305': 3, 'm_202306': 10, 'm_202307': 10, 'm_202308': 3, 'm_202309': 4, 'm_202310': 42, 'm_202311': 6, 'm_202312': 4, 'm_202401': 6, 'average': 6}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 1499/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@hyper.fun/fluentui-icon-notebook-question-mark-regular', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 0, 'm_202204': 0, 'm_202205': 0, 'm_202206': 0, 'm_202207': 0, 'm_202208': 68, 'm_202209': 33, 'm_202210': 7, 'm_202211': 4, 'm_202212': 4, 'm_202301': 62, 'm_202302': 15, 'm_202303': 4, 'm_202304': 7, 'm_202305': 2, 'm_202306': 4, 'm_202307': 7, 'm_202308': 3, 'm_202309': 6, 'm_202310': 19, 'm_202311': 12, 'm_202312': 16, 'm_202401': 3, 'average': 4}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 1500/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@pie-cli-libs/installer', 'm_201805': 70, 'm_201806': 231, 'm_201807': 159, 'm_201808': 111, 'm_201809': 29, 'm_201810': 47, 'm_201811': 55, 'm_201812': 96, 'm_201901': 62, 'm_201902': 31, 'm_201903': 18, 'm_201904': 90, 'm_201905': 44, 'm_201906': 134, 'm_201907': 197, 'm_201908': 118, 'm_201909': 47, 'm_201910': 13, 'm_201911': 32, 'm_201912': 32, 'm_202001': 145, 'm_202002': 38, 'm_202003': 30, 'm_202004': 25, 'm_202005': 32, 'm_202006': 31, 'm_202007': 15, 'm_202008': 41, 'm_202009': 29, 'm_202010': 53, 'm_202011': 68, 'm_202012': 49, 'm_202101': 39, 'm_202102': 25, 'm_202103': 84, 'm_202104': 69, 'm_202105': 50, 'm_202106': 58, 'm_202107': 91, 'm_202108': 49, 'm_202109': 83, 'm_202110': 42, 'm_202111': 34, 'm_202112': 94, 'm_202201': 57, 'm_202202': 38, 'm_202203': 41, 'm_202204': 82, 'm_202205': 80, 'm_202206': 40, 'm_202207': 30, 'm_202208': 107, 'm_202209': 100, 'm_202210': 46, 'm_202211': 57, 'm_202212': 43, 'm_202301': 54, 'm_202302': 34, 'm_202303': 67, 'm_202304': 55, 'm_202305': 22, 'm_202306': 77, 'm_202307': 127, 'm_202308': 96, 'm_202309': 49, 'm_202310': 342, 'm_202311': 28, 'm_202312': 35, 'm_202401': 43, 'average': 67}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 1501/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@lcu/hosting', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 437, 'm_201901': 623, 'm_201902': 667, 'm_201903': 638, 'm_201904': 723, 'm_201905': 90, 'm_201906': 274, 'm_201907': 410, 'm_201908': 23, 'm_201909': 4, 'm_201910': 15, 'm_201911': 131, 'm_201912': 6, 'm_202001': 201, 'm_202002': 59, 'm_202003': 6, 'm_202004': 23, 'm_202005': 28, 'm_202006': 44, 'm_202007': 11, 'm_202008': 19, 'm_202009': 139, 'm_202010': 202, 'm_202011': 59, 'm_202012': 21, 'm_202101': 48, 'm_202102': 311, 'm_202103': 594, 'm_202104': 273, 'm_202105': 176, 'm_202106': 69, 'm_202107': 215, 'm_202108': 164, 'm_202109': 80, 'm_202110': 6, 'm_202111': 3, 'm_202112': 77, 'm_202201': 156, 'm_202202': 61, 'm_202203': 123, 'm_202204': 219, 'm_202205': 197, 'm_202206': 50, 'm_202207': 43, 'm_202208': 243, 'm_202209': 209, 'm_202210': 142, 'm_202211': 236, 'm_202212': 16, 'm_202301': 102, 'm_202302': 89, 'm_202303': 98, 'm_202304': 150, 'm_202305': 87, 'm_202306': 89, 'm_202307': 48, 'm_202308': 40, 'm_202309': 122, 'm_202310': 457, 'm_202311': 42, 'm_202312': 37, 'm_202401': 134, 'average': 145}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 1502/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@chirpy-dev/service-worker', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 0, 'm_202204': 0, 'm_202205': 88, 'm_202206': 15, 'm_202207': 17, 'm_202208': 155, 'm_202209': 25, 'm_202210': 11, 'm_202211': 6, 'm_202212': 6, 'm_202301': 13, 'm_202302': 8, 'm_202303': 8, 'm_202304': 9, 'm_202305': 2, 'm_202306': 7, 'm_202307': 10, 'm_202308': 4, 'm_202309': 29, 'm_202310': 33, 'm_202311': 10, 'm_202312': 5, 'm_202401': 8, 'average': 6}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 1503/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@cymmetrik/graphql-tower-jwt', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 171, 'm_202012': 25, 'm_202101': 14, 'm_202102': 13, 'm_202103': 20, 'm_202104': 17, 'm_202105': 12, 'm_202106': 31, 'm_202107': 40, 'm_202108': 30, 'm_202109': 31, 'm_202110': 4, 'm_202111': 6, 'm_202112': 12, 'm_202201': 14, 'm_202202': 10, 'm_202203': 38, 'm_202204': 29, 'm_202205': 10, 'm_202206': 11, 'm_202207': 21, 'm_202208': 27, 'm_202209': 28, 'm_202210': 19, 'm_202211': 8, 'm_202212': 10, 'm_202301': 16, 'm_202302': 4, 'm_202303': 20, 'm_202304': 9, 'm_202305': 3, 'm_202306': 12, 'm_202307': 13, 'm_202308': 6, 'm_202309': 39, 'm_202310': 62, 'm_202311': 14, 'm_202312': 8, 'm_202401': 12, 'average': 12}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 1504/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@riveroreyes/optare-direcciones-edit', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 1410, 'm_202006': 439, 'm_202007': 4, 'm_202008': 26, 'm_202009': 122, 'm_202010': 186, 'm_202011': 89, 'm_202012': 24, 'm_202101': 6, 'm_202102': 195, 'm_202103': 487, 'm_202104': 237, 'm_202105': 124, 'm_202106': 93, 'm_202107': 92, 'm_202108': 103, 'm_202109': 106, 'm_202110': 10, 'm_202111': 99, 'm_202112': 36, 'm_202201': 130, 'm_202202': 99, 'm_202203': 51, 'm_202204': 158, 'm_202205': 171, 'm_202206': 5, 'm_202207': 75, 'm_202208': 187, 'm_202209': 200, 'm_202210': 75, 'm_202211': 99, 'm_202212': 65, 'm_202301': 108, 'm_202302': 106, 'm_202303': 89, 'm_202304': 45, 'm_202305': 8, 'm_202306': 97, 'm_202307': 43, 'm_202308': 54, 'm_202309': 65, 'm_202310': 397, 'm_202311': 71, 'm_202312': 4, 'm_202401': 100, 'average': 92}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 1505/1673
# ==============================================================================
#
#
# Rows fetched in 1	seconds
# {'package': '@affinidi/affinidi-uaf-client-lib', 'm_201805': 0, 'm_201806': 0, 'm_201807': 0, 'm_201808': 0, 'm_201809': 0, 'm_201810': 0, 'm_201811': 0, 'm_201812': 0, 'm_201901': 0, 'm_201902': 0, 'm_201903': 0, 'm_201904': 0, 'm_201905': 0, 'm_201906': 0, 'm_201907': 0, 'm_201908': 0, 'm_201909': 0, 'm_201910': 0, 'm_201911': 0, 'm_201912': 0, 'm_202001': 0, 'm_202002': 0, 'm_202003': 0, 'm_202004': 0, 'm_202005': 0, 'm_202006': 0, 'm_202007': 0, 'm_202008': 0, 'm_202009': 0, 'm_202010': 0, 'm_202011': 0, 'm_202012': 0, 'm_202101': 0, 'm_202102': 0, 'm_202103': 0, 'm_202104': 0, 'm_202105': 0, 'm_202106': 0, 'm_202107': 0, 'm_202108': 0, 'm_202109': 0, 'm_202110': 0, 'm_202111': 0, 'm_202112': 0, 'm_202201': 0, 'm_202202': 0, 'm_202203': 151, 'm_202204': 153, 'm_202205': 29, 'm_202206': 75, 'm_202207': 52, 'm_202208': 75, 'm_202209': 47, 'm_202210': 23, 'm_202211': 44, 'm_202212': 14, 'm_202301': 16, 'm_202302': 22, 'm_202303': 6, 'm_202304': 9, 'm_202305': 11, 'm_202306': 21, 'm_202307': 13, 'm_202308': 6, 'm_202309': 7, 'm_202310': 41, 'm_202311': 6, 'm_202312': 5, 'm_202401': 10, 'average': 12}
# ==============================================================================
# Database updated in 0 seconds
# Rows fetched so far: 1506/1673
# ==============================================================================

# %%
conn.close()
