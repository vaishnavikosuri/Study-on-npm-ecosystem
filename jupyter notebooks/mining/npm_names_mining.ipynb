# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import subprocess
import pandas as pd
import requests
from urllib.parse import urljoin
import sqlite3
import json
import time

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
os.chdir("/content/gdrive/Shareddrives/ECS 260")
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# # DB Init

# %%
# db init
# db_columns = ['package', 'id', 'key', 'value', 'meta_data']
# df = pd.DataFrame(columns=db_columns)

conn = sqlite3.connect('npm_names.db')
cursor = conn.cursor()

# Create a table in the database
cursor.execute('''
    CREATE TABLE IF NOT EXISTS npm_package_names (
        package TEXT
    )
''')
conn.commit()

# %% [markdown]
# # Function Definitions and inits

# %%
def fetch_response_with_retry(url, limit, skip, startkey = '', max_retries=3):
    retry_count = 0

    while retry_count < max_retries:
        try:
            params = {
                'limit': limit,
                'skip': skip,
                'startkey_docid': startkey,
                # 'include_docs': 'true'  # include package metadata in the response
            }

            response = requests.get(url, params=params)

            if response.status_code == 200:
                return response.json()
            else:
                print(f"Error: {response.status_code}")
                print(params)
                retry_count += 1
                print(f"Retrying in 5 seconds... (Retry {retry_count}/{max_retries})")
                time.sleep(5)

        except Exception as e:
            print(f"Exception occurred: {e}")
            retry_count += 1
            print(f"Retrying in 5 seconds... (Retry {retry_count}/{max_retries})")
            time.sleep(5)

    print(f"Max retries reached. Unable to fetch data from {url}.")
    return None

# %%
npm_base = "https://replicate.npmjs.com/"
all_endpoint = '_all_docs'
url = urljoin(npm_base, all_endpoint)

# %%
cursor.execute('SELECT COUNT(*) FROM npm_package_names')
rows_fetched = cursor.fetchone()[0]
print(f"Names mined so far: {rows_fetched}")
# Out:
# Names mined so far: 1230000

# %%
cursor.execute('''
    SELECT * FROM npm_package_names
    ORDER BY package DESC
''')

last_row = cursor.fetchone()
last_row_key = last_row[0]
print(f"Last package mined --> {last_row_key}")
# Out:
# Last package mined --> discord-minimal

# %%
total_packages_available = 2682257
total_rows = total_packages_available/2 + 1
rows_per_page = 250

# %%
page_json_response = fetch_response_with_retry(url, rows_per_page, 0, last_row_key)

# %%
page_json_response["rows"][0]
# Out:
# {'id': 'discord-minimal',
#  'key': 'discord-minimal',
#  'value': {'rev': '72-6b78b945880a0d6dca55602b2854d15e'}}

# %% [markdown]
# # Mining

# %%
curr_offset = 1 if last_row_key else 0

if last_row_key:
  while rows_fetched < total_rows:
    api_call_start_time = time.time()


    page_json_response = fetch_response_with_retry(url, rows_per_page, curr_offset, last_row_key)


    api_call_end_time = time.time()
    elapsed_api_call_time = api_call_end_time - api_call_start_time

    db_update_start_time = time.time()

    if page_json_response:
      rows_fetched += rows_per_page


      print("Rows fetched: " + str(rows_fetched) + "\tin " + str(elapsed_api_call_time) + "\tseconds")

      curr_offset = 1
      last_row_key = page_json_response['rows'][-1]['key']

      packages = [(row['key'],) for row in page_json_response['rows']]
      # updating db
      cursor.executemany('''
              INSERT INTO npm_package_names (package)
              VALUES (?)
          ''', packages)
      conn.commit()

      db_update_end_time = time.time()
      elapsed_db_update_time = db_update_end_time - db_update_start_time
      print("Dataframe and database updated in " + str(elapsed_db_update_time) + " seconds")
      print()
# Out:
# Rows fetched: 1230250	in 20.583998680114746	seconds
# Dataframe and database updated in 0.03553342819213867 seconds
#
# Rows fetched: 1230500	in 14.896684408187866	seconds
# Dataframe and database updated in 0.021087646484375 seconds
#
# Rows fetched: 1230750	in 20.776349544525146	seconds
# Dataframe and database updated in 0.01895308494567871 seconds
#
# Rows fetched: 1231000	in 13.225515127182007	seconds
# Dataframe and database updated in 0.020948410034179688 seconds
#
# Rows fetched: 1231250	in 20.10891318321228	seconds
# Dataframe and database updated in 0.01836228370666504 seconds
#
# Rows fetched: 1231500	in 18.559289932250977	seconds
# Dataframe and database updated in 0.034837961196899414 seconds
#
# Rows fetched: 1231750	in 6.800427675247192	seconds
# Dataframe and database updated in 0.018511056900024414 seconds
#
# Rows fetched: 1232000	in 4.994453191757202	seconds
# Dataframe and database updated in 0.02300262451171875 seconds
#
# Rows fetched: 1232250	in 8.093596696853638	seconds
# Dataframe and database updated in 0.018809795379638672 seconds
#
# Rows fetched: 1232500	in 4.004396200180054	seconds
# Dataframe and database updated in 0.017056703567504883 seconds
#
# Rows fetched: 1232750	in 3.4904792308807373	seconds
# Dataframe and database updated in 0.016414880752563477 seconds
#
# Rows fetched: 1233000	in 4.337865352630615	seconds
# Dataframe and database updated in 0.01595449447631836 seconds
#
# Rows fetched: 1233250	in 8.327158689498901	seconds
# Dataframe and database updated in 0.018450260162353516 seconds
#
# Rows fetched: 1233500	in 5.887860536575317	seconds
# Dataframe and database updated in 0.016472816467285156 seconds
#
# Rows fetched: 1233750	in 7.272126197814941	seconds
# Dataframe and database updated in 0.03801369667053223 seconds
#
# Rows fetched: 1234000	in 6.341071128845215	seconds
# Dataframe and database updated in 0.015851497650146484 seconds
#
# Rows fetched: 1234250	in 12.065749883651733	seconds
# Dataframe and database updated in 0.016229867935180664 seconds
#
# Rows fetched: 1234500	in 5.657507658004761	seconds
# Dataframe and database updated in 0.015955448150634766 seconds
#
# Rows fetched: 1234750	in 3.9052586555480957	seconds
# Dataframe and database updated in 0.016338586807250977 seconds
#
# Rows fetched: 1235000	in 6.554661989212036	seconds
# Dataframe and database updated in 0.017302513122558594 seconds
#
# Rows fetched: 1235250	in 3.066084861755371	seconds
# Dataframe and database updated in 0.014827966690063477 seconds
#
# Rows fetched: 1235500	in 3.886295795440674	seconds
# Dataframe and database updated in 0.017770051956176758 seconds
#
# Rows fetched: 1235750	in 6.490948915481567	seconds
# Dataframe and database updated in 0.018323421478271484 seconds
#
# Rows fetched: 1236000	in 4.579457998275757	seconds
# Dataframe and database updated in 0.03874039649963379 seconds
#
# Rows fetched: 1236250	in 7.466871500015259	seconds
# Dataframe and database updated in 0.018955230712890625 seconds
#
# Rows fetched: 1236500	in 6.487277984619141	seconds
# Dataframe and database updated in 0.017427444458007812 seconds
#
# Rows fetched: 1236750	in 5.997110843658447	seconds
# Dataframe and database updated in 0.02137017250061035 seconds
#
# Rows fetched: 1237000	in 5.720806121826172	seconds
# Dataframe and database updated in 0.018427133560180664 seconds
#
# Rows fetched: 1237250	in 3.068638563156128	seconds
# Dataframe and database updated in 0.018288135528564453 seconds
#
# Rows fetched: 1237500	in 3.1280710697174072	seconds
# Dataframe and database updated in 0.017310380935668945 seconds
#
# Rows fetched: 1237750	in 8.282861948013306	seconds
# Dataframe and database updated in 0.01632547378540039 seconds
#
# Rows fetched: 1238000	in 9.155247211456299	seconds
# Dataframe and database updated in 0.04122304916381836 seconds
#
# Rows fetched: 1238250	in 11.24901294708252	seconds
# Dataframe and database updated in 0.01766180992126465 seconds
#
# Rows fetched: 1238500	in 9.205584526062012	seconds
# Dataframe and database updated in 0.01923990249633789 seconds
#
# Rows fetched: 1238750	in 4.473312854766846	seconds
# Dataframe and database updated in 0.017973661422729492 seconds
#
# Rows fetched: 1239000	in 9.630487442016602	seconds
# Dataframe and database updated in 0.019696950912475586 seconds
#
# Rows fetched: 1239250	in 18.070782899856567	seconds
# Dataframe and database updated in 0.018248319625854492 seconds
#
# Rows fetched: 1239500	in 8.977905035018921	seconds
# Dataframe and database updated in 0.017734766006469727 seconds
#
# Rows fetched: 1239750	in 7.308440685272217	seconds
# Dataframe and database updated in 0.022663354873657227 seconds
#
# Rows fetched: 1240000	in 7.951922416687012	seconds
# Dataframe and database updated in 0.01676797866821289 seconds
#
# Rows fetched: 1240250	in 6.610974550247192	seconds
# Dataframe and database updated in 0.04373788833618164 seconds
#
# Rows fetched: 1240500	in 3.3616790771484375	seconds
# Dataframe and database updated in 0.019028663635253906 seconds
#
# Rows fetched: 1240750	in 3.1195430755615234	seconds
# Dataframe and database updated in 0.020512104034423828 seconds
#
# Rows fetched: 1241000	in 2.853389263153076	seconds
# Dataframe and database updated in 0.020331382751464844 seconds
#
# Rows fetched: 1241250	in 10.555936098098755	seconds
# Dataframe and database updated in 0.01830577850341797 seconds
#
# Rows fetched: 1241500	in 18.075238466262817	seconds
# Dataframe and database updated in 0.021546125411987305 seconds
#
# Rows fetched: 1241750	in 29.802859783172607	seconds
# Dataframe and database updated in 0.018051862716674805 seconds
#
# Rows fetched: 1242000	in 5.957932472229004	seconds
# Dataframe and database updated in 0.01869344711303711 seconds
#
# Rows fetched: 1242250	in 4.417422771453857	seconds
# Dataframe and database updated in 0.03205680847167969 seconds
#
# Rows fetched: 1242500	in 7.899677276611328	seconds
# Dataframe and database updated in 0.018587589263916016 seconds
#
# Rows fetched: 1242750	in 6.062510251998901	seconds
# Dataframe and database updated in 0.020685672760009766 seconds
#
# Rows fetched: 1243000	in 7.315823078155518	seconds
# Dataframe and database updated in 0.013895988464355469 seconds
#
# Rows fetched: 1243250	in 4.879612922668457	seconds
# Dataframe and database updated in 0.021589279174804688 seconds
#
# Rows fetched: 1243500	in 3.9488391876220703	seconds
# Dataframe and database updated in 0.018533945083618164 seconds
#
# Rows fetched: 1243750	in 4.348724126815796	seconds
# Dataframe and database updated in 0.016574382781982422 seconds
#
# Rows fetched: 1244000	in 5.091755628585815	seconds
# Dataframe and database updated in 0.01738905906677246 seconds
#
# Rows fetched: 1244250	in 2.696742296218872	seconds
# Dataframe and database updated in 0.01784825325012207 seconds
#
# Rows fetched: 1244500	in 3.8097734451293945	seconds
# Dataframe and database updated in 0.023096799850463867 seconds
#
# Rows fetched: 1244750	in 5.690269708633423	seconds
# Dataframe and database updated in 0.03728938102722168 seconds
#
# Rows fetched: 1245000	in 7.40189266204834	seconds
# Dataframe and database updated in 0.016184568405151367 seconds
#
# Rows fetched: 1245250	in 4.425934314727783	seconds
# Dataframe and database updated in 0.014911413192749023 seconds
#
# Rows fetched: 1245500	in 11.514411211013794	seconds
# Dataframe and database updated in 0.01720595359802246 seconds
#
# Rows fetched: 1245750	in 4.520478010177612	seconds
# Dataframe and database updated in 0.016359329223632812 seconds
#
# Rows fetched: 1246000	in 18.877670764923096	seconds
# Dataframe and database updated in 0.017841339111328125 seconds
#
# Rows fetched: 1246250	in 5.694172620773315	seconds
# Dataframe and database updated in 0.026926755905151367 seconds
#
# Rows fetched: 1246500	in 14.111807584762573	seconds
# Dataframe and database updated in 0.0166475772857666 seconds
#
# Rows fetched: 1246750	in 8.189871072769165	seconds
# Dataframe and database updated in 0.016329050064086914 seconds
#
# Rows fetched: 1247000	in 6.2327680587768555	seconds
# Dataframe and database updated in 0.03322577476501465 seconds
#
# Rows fetched: 1247250	in 6.6198530197143555	seconds
# Dataframe and database updated in 0.0184476375579834 seconds
#
# Rows fetched: 1247500	in 9.730860471725464	seconds
# Dataframe and database updated in 0.016638994216918945 seconds
#
# Rows fetched: 1247750	in 8.643469095230103	seconds
# Dataframe and database updated in 0.016245126724243164 seconds
#
# Rows fetched: 1248000	in 6.446166753768921	seconds
# Dataframe and database updated in 0.016021251678466797 seconds
#
# Rows fetched: 1248250	in 13.27761435508728	seconds
# Dataframe and database updated in 0.01849198341369629 seconds
#
# Rows fetched: 1248500	in 25.854374408721924	seconds
# Dataframe and database updated in 0.01638317108154297 seconds
#
# Rows fetched: 1248750	in 23.8104829788208	seconds
# Dataframe and database updated in 0.018854618072509766 seconds
#
# Rows fetched: 1249000	in 10.91311001777649	seconds
# Dataframe and database updated in 0.02130913734436035 seconds
#
# Rows fetched: 1249250	in 7.307393550872803	seconds
# Dataframe and database updated in 0.03950333595275879 seconds
#
# Rows fetched: 1249500	in 13.660966157913208	seconds
# Dataframe and database updated in 0.01942729949951172 seconds
#
# Rows fetched: 1249750	in 4.446985483169556	seconds
# Dataframe and database updated in 0.018798351287841797 seconds
#
# Rows fetched: 1250000	in 9.51657748222351	seconds
# Dataframe and database updated in 0.021131515502929688 seconds
#
# Rows fetched: 1250250	in 20.603174448013306	seconds
# Dataframe and database updated in 0.016776561737060547 seconds
#
# Rows fetched: 1250500	in 20.638662576675415	seconds
# Dataframe and database updated in 0.022441625595092773 seconds
#
# Rows fetched: 1250750	in 6.534961700439453	seconds
# Dataframe and database updated in 0.018205642700195312 seconds
#
# Rows fetched: 1251000	in 6.637151718139648	seconds
# Dataframe and database updated in 0.0162198543548584 seconds
#
# Rows fetched: 1251250	in 9.559520483016968	seconds
# Dataframe and database updated in 0.03370261192321777 seconds
#
# Rows fetched: 1251500	in 48.6944363117218	seconds
# Dataframe and database updated in 0.017203807830810547 seconds
#
# Rows fetched: 1251750	in 3.026275396347046	seconds
# Dataframe and database updated in 0.017589092254638672 seconds
#
# Rows fetched: 1252000	in 3.3697166442871094	seconds
# Dataframe and database updated in 0.02039647102355957 seconds
#
# Rows fetched: 1252250	in 3.2618558406829834	seconds
# Dataframe and database updated in 0.01968979835510254 seconds
#
# Rows fetched: 1252500	in 3.291689395904541	seconds
# Dataframe and database updated in 0.017584800720214844 seconds
#
# Rows fetched: 1252750	in 2.4523298740386963	seconds
# Dataframe and database updated in 0.017293214797973633 seconds
#
# Rows fetched: 1253000	in 4.28522801399231	seconds
# Dataframe and database updated in 0.017528057098388672 seconds
#
# Rows fetched: 1253250	in 3.872922897338867	seconds
# Dataframe and database updated in 0.01764369010925293 seconds
#
# Rows fetched: 1253500	in 3.4012198448181152	seconds
# Dataframe and database updated in 0.035227060317993164 seconds
#
# Rows fetched: 1253750	in 4.470039367675781	seconds
# Dataframe and database updated in 0.015879154205322266 seconds
#
# Rows fetched: 1254000	in 3.6877875328063965	seconds
# Dataframe and database updated in 0.017058849334716797 seconds
#
# Rows fetched: 1254250	in 4.668914794921875	seconds
# Dataframe and database updated in 0.018368244171142578 seconds
#
# Rows fetched: 1254500	in 2.8040740489959717	seconds
# Dataframe and database updated in 0.017592191696166992 seconds
#
# Rows fetched: 1254750	in 2.584007740020752	seconds
# Dataframe and database updated in 0.01672840118408203 seconds
#
# Rows fetched: 1255000	in 3.3701608180999756	seconds
# Dataframe and database updated in 0.020401716232299805 seconds
#
# Rows fetched: 1255250	in 4.126862049102783	seconds
# Dataframe and database updated in 0.01915144920349121 seconds
#
# Rows fetched: 1255500	in 3.2170066833496094	seconds
# Dataframe and database updated in 0.01820516586303711 seconds
#
# Rows fetched: 1255750	in 2.3795888423919678	seconds
# Dataframe and database updated in 0.04266548156738281 seconds
#
# Rows fetched: 1256000	in 3.3355553150177	seconds
# Dataframe and database updated in 0.018682003021240234 seconds
#
# Rows fetched: 1256250	in 5.8955724239349365	seconds
# Dataframe and database updated in 0.01690363883972168 seconds
#
# Rows fetched: 1256500	in 6.0832600593566895	seconds
# Dataframe and database updated in 0.02119731903076172 seconds
#
# Rows fetched: 1256750	in 7.233301639556885	seconds
# Dataframe and database updated in 0.01740241050720215 seconds
#
# Rows fetched: 1257000	in 7.1893630027771	seconds
# Dataframe and database updated in 0.02043461799621582 seconds
#
# Rows fetched: 1257250	in 5.935450315475464	seconds
# Dataframe and database updated in 0.017082691192626953 seconds
#
# Rows fetched: 1257500	in 11.335304260253906	seconds
# Dataframe and database updated in 0.017299890518188477 seconds
#
# Rows fetched: 1257750	in 4.555537939071655	seconds
# Dataframe and database updated in 0.03506278991699219 seconds
#
# Rows fetched: 1258000	in 7.933722257614136	seconds
# Dataframe and database updated in 0.01566600799560547 seconds
#
# Rows fetched: 1258250	in 9.298039436340332	seconds
# Dataframe and database updated in 0.01896190643310547 seconds
#
# Rows fetched: 1258500	in 7.894121885299683	seconds
# Dataframe and database updated in 0.017177581787109375 seconds
#
# Rows fetched: 1258750	in 5.953179359436035	seconds
# Dataframe and database updated in 0.020270109176635742 seconds
#
# Rows fetched: 1259000	in 8.557438135147095	seconds
# Dataframe and database updated in 0.016383886337280273 seconds
#
# Rows fetched: 1259250	in 5.565966606140137	seconds
# Dataframe and database updated in 0.017417430877685547 seconds
#
# Rows fetched: 1259500	in 7.40599799156189	seconds
# Dataframe and database updated in 0.016864776611328125 seconds
#
# Rows fetched: 1259750	in 8.591019868850708	seconds
# Dataframe and database updated in 0.01775956153869629 seconds
#
# Rows fetched: 1260000	in 8.032638549804688	seconds
# Dataframe and database updated in 0.04146313667297363 seconds
#
# Rows fetched: 1260250	in 7.037059783935547	seconds
# Dataframe and database updated in 0.017901897430419922 seconds
#
# Rows fetched: 1260500	in 7.94512414932251	seconds
# Dataframe and database updated in 0.01811385154724121 seconds
#
# Rows fetched: 1260750	in 11.95208740234375	seconds
# Dataframe and database updated in 0.01741504669189453 seconds
#
# Rows fetched: 1261000	in 8.628478527069092	seconds
# Dataframe and database updated in 0.019798994064331055 seconds
#
# Rows fetched: 1261250	in 7.2598114013671875	seconds
# Dataframe and database updated in 0.01797318458557129 seconds
#
# Rows fetched: 1261500	in 13.638074159622192	seconds
# Dataframe and database updated in 0.01900649070739746 seconds
#
# Rows fetched: 1261750	in 20.290274143218994	seconds
# Dataframe and database updated in 0.019208669662475586 seconds
#
# Rows fetched: 1262000	in 12.095999002456665	seconds
# Dataframe and database updated in 0.02092432975769043 seconds
#
# Rows fetched: 1262250	in 8.843746185302734	seconds
# Dataframe and database updated in 0.03468918800354004 seconds
#
# Rows fetched: 1262500	in 14.009344577789307	seconds
# Dataframe and database updated in 0.01906728744506836 seconds
#
# Rows fetched: 1262750	in 6.902714014053345	seconds
# Dataframe and database updated in 0.01899266242980957 seconds
#
# Rows fetched: 1263000	in 4.147623062133789	seconds
# Dataframe and database updated in 0.017477035522460938 seconds
#
# Rows fetched: 1263250	in 5.228942155838013	seconds
# Dataframe and database updated in 0.019997596740722656 seconds
#
# Rows fetched: 1263500	in 5.132152080535889	seconds
# Dataframe and database updated in 0.02022528648376465 seconds
#
# Rows fetched: 1263750	in 5.237001895904541	seconds
# Dataframe and database updated in 0.02008223533630371 seconds
#
# Rows fetched: 1264000	in 5.712565898895264	seconds
# Dataframe and database updated in 0.01610422134399414 seconds
#
# Rows fetched: 1264250	in 7.103870153427124	seconds
# Dataframe and database updated in 0.019664764404296875 seconds
#
# Rows fetched: 1264500	in 7.066727876663208	seconds
# Dataframe and database updated in 0.03212928771972656 seconds
#
# Rows fetched: 1264750	in 5.86838960647583	seconds
# Dataframe and database updated in 0.0205533504486084 seconds
#
# Rows fetched: 1265000	in 7.630321025848389	seconds
# Dataframe and database updated in 0.016828536987304688 seconds
#
# Rows fetched: 1265250	in 10.380513668060303	seconds
# Dataframe and database updated in 0.014446496963500977 seconds
#
# Rows fetched: 1265500	in 11.703810453414917	seconds
# Dataframe and database updated in 0.022975444793701172 seconds
#
# Rows fetched: 1265750	in 9.127951383590698	seconds
# Dataframe and database updated in 0.01458287239074707 seconds
#
# Rows fetched: 1266000	in 5.8518688678741455	seconds
# Dataframe and database updated in 0.024000883102416992 seconds
#
# Rows fetched: 1266250	in 4.374093055725098	seconds
# Dataframe and database updated in 0.018752098083496094 seconds
#
# Rows fetched: 1266500	in 11.71410584449768	seconds
# Dataframe and database updated in 0.014061212539672852 seconds
#
# Rows fetched: 1266750	in 15.45634150505066	seconds
# Dataframe and database updated in 0.03013896942138672 seconds
#
# Rows fetched: 1267000	in 10.270615339279175	seconds
# Dataframe and database updated in 0.020119905471801758 seconds
#
# Rows fetched: 1267250	in 12.59735655784607	seconds
# Dataframe and database updated in 0.018785715103149414 seconds
#
# Rows fetched: 1267500	in 11.330700635910034	seconds
# Dataframe and database updated in 0.017115116119384766 seconds
#
# Rows fetched: 1267750	in 12.264955520629883	seconds
# Dataframe and database updated in 0.022040605545043945 seconds
#
# Rows fetched: 1268000	in 6.418889999389648	seconds
# Dataframe and database updated in 0.018123388290405273 seconds
#
# Rows fetched: 1268250	in 7.601389646530151	seconds
# Dataframe and database updated in 0.01895308494567871 seconds
#
# Rows fetched: 1268500	in 5.608007192611694	seconds
# Dataframe and database updated in 0.017632246017456055 seconds
#
# Rows fetched: 1268750	in 9.817277431488037	seconds
# Dataframe and database updated in 0.036568641662597656 seconds
#
# Rows fetched: 1269000	in 14.850765943527222	seconds
# Dataframe and database updated in 0.016987323760986328 seconds
#
# Rows fetched: 1269250	in 6.831339120864868	seconds
# Dataframe and database updated in 0.017258405685424805 seconds
#
# Rows fetched: 1269500	in 7.4315831661224365	seconds
# Dataframe and database updated in 0.01762843132019043 seconds
#
# Rows fetched: 1269750	in 10.614197492599487	seconds
# Dataframe and database updated in 0.017360925674438477 seconds
#
# Rows fetched: 1270000	in 51.57818818092346	seconds
# Dataframe and database updated in 0.01821303367614746 seconds
#
# Rows fetched: 1270250	in 15.960491418838501	seconds
# Dataframe and database updated in 0.014915943145751953 seconds
#
# Rows fetched: 1270500	in 4.731160640716553	seconds
# Dataframe and database updated in 0.017677783966064453 seconds
#
# Rows fetched: 1270750	in 6.3260626792907715	seconds
# Dataframe and database updated in 0.016976594924926758 seconds
#
# Rows fetched: 1271000	in 5.374378204345703	seconds
# Dataframe and database updated in 0.03652048110961914 seconds
#
# Rows fetched: 1271250	in 4.349143743515015	seconds
# Dataframe and database updated in 0.01746201515197754 seconds
#
# Rows fetched: 1271500	in 2.2270286083221436	seconds
# Dataframe and database updated in 0.017947673797607422 seconds
#
# Rows fetched: 1271750	in 7.153116703033447	seconds
# Dataframe and database updated in 0.019061565399169922 seconds
#
# Rows fetched: 1272000	in 2.8654279708862305	seconds
# Dataframe and database updated in 0.018726110458374023 seconds
#
# Rows fetched: 1272250	in 4.337799072265625	seconds
# Dataframe and database updated in 0.01712346076965332 seconds
#
# Rows fetched: 1272500	in 5.192593336105347	seconds
# Dataframe and database updated in 0.017017126083374023 seconds
#
# Rows fetched: 1272750	in 3.3825056552886963	seconds
# Dataframe and database updated in 0.01691436767578125 seconds
#
# Rows fetched: 1273000	in 2.883012533187866	seconds
# Dataframe and database updated in 0.015243291854858398 seconds
#
# Rows fetched: 1273250	in 6.657154560089111	seconds
# Dataframe and database updated in 0.03372478485107422 seconds
#
# Rows fetched: 1273500	in 4.441861391067505	seconds
# Dataframe and database updated in 0.020517349243164062 seconds
#
# Rows fetched: 1273750	in 8.141651391983032	seconds
# Dataframe and database updated in 0.01689004898071289 seconds
#
# Rows fetched: 1274000	in 3.807631731033325	seconds
# Dataframe and database updated in 0.019285917282104492 seconds
#
# Rows fetched: 1274250	in 5.838303565979004	seconds
# Dataframe and database updated in 0.018590450286865234 seconds
#
# Rows fetched: 1274500	in 3.6510331630706787	seconds
# Dataframe and database updated in 0.021461963653564453 seconds
#
# Rows fetched: 1274750	in 4.201354026794434	seconds
# Dataframe and database updated in 0.014652729034423828 seconds
#
# Rows fetched: 1275000	in 6.447131395339966	seconds
# Dataframe and database updated in 0.01644110679626465 seconds
#
# Rows fetched: 1275250	in 2.8087029457092285	seconds
# Dataframe and database updated in 0.018433332443237305 seconds
#
# Rows fetched: 1275500	in 4.388365030288696	seconds
# Dataframe and database updated in 0.03992938995361328 seconds
#
# Rows fetched: 1275750	in 7.922961235046387	seconds
# Dataframe and database updated in 0.020876169204711914 seconds
#
# Rows fetched: 1276000	in 6.2793128490448	seconds
# Dataframe and database updated in 0.01933574676513672 seconds
#
# Rows fetched: 1276250	in 11.514898777008057	seconds
# Dataframe and database updated in 0.017386198043823242 seconds
#
# Rows fetched: 1276500	in 4.999762773513794	seconds
# Dataframe and database updated in 0.017007112503051758 seconds
#
# Rows fetched: 1276750	in 10.668514490127563	seconds
# Dataframe and database updated in 0.018486499786376953 seconds
#
# Rows fetched: 1277000	in 7.329291820526123	seconds
# Dataframe and database updated in 0.018363475799560547 seconds
#
# Rows fetched: 1277250	in 6.038520812988281	seconds
# Dataframe and database updated in 0.019465208053588867 seconds
#
# Rows fetched: 1277500	in 8.521246671676636	seconds
# Dataframe and database updated in 0.02919936180114746 seconds
#
# Rows fetched: 1277750	in 15.397533893585205	seconds
# Dataframe and database updated in 0.022365808486938477 seconds
#
# Rows fetched: 1278000	in 11.935386180877686	seconds
# Dataframe and database updated in 0.01885843276977539 seconds
#
# Rows fetched: 1278250	in 4.071011304855347	seconds
# Dataframe and database updated in 0.01671123504638672 seconds
#
# Rows fetched: 1278500	in 7.39821720123291	seconds
# Dataframe and database updated in 0.017420291900634766 seconds
#
# Rows fetched: 1278750	in 25.096299409866333	seconds
# Dataframe and database updated in 0.018492937088012695 seconds
#
# Rows fetched: 1279000	in 22.385778665542603	seconds
# Dataframe and database updated in 0.01842045783996582 seconds
#
# Rows fetched: 1279250	in 6.753262281417847	seconds
# Dataframe and database updated in 0.018741846084594727 seconds
#
# Rows fetched: 1279500	in 4.0026466846466064	seconds
# Dataframe and database updated in 0.018132686614990234 seconds
#
# Rows fetched: 1279750	in 7.5899574756622314	seconds
# Dataframe and database updated in 0.04549765586853027 seconds
#
# Rows fetched: 1280000	in 3.2443082332611084	seconds
# Dataframe and database updated in 0.0215303897857666 seconds
#
# Rows fetched: 1280250	in 3.7033843994140625	seconds
# Dataframe and database updated in 0.01760125160217285 seconds
#
# Rows fetched: 1280500	in 5.42580509185791	seconds
# Dataframe and database updated in 0.01907491683959961 seconds
#
# Rows fetched: 1280750	in 4.401081323623657	seconds
# Dataframe and database updated in 0.0184478759765625 seconds
#
# Rows fetched: 1281000	in 3.6254756450653076	seconds
# Dataframe and database updated in 0.0171816349029541 seconds
#
# Rows fetched: 1281250	in 4.0887291431427	seconds
# Dataframe and database updated in 0.019278526306152344 seconds
#
# Rows fetched: 1281500	in 2.890439033508301	seconds
# Dataframe and database updated in 0.018609046936035156 seconds
#
# Rows fetched: 1281750	in 2.869771957397461	seconds
# Dataframe and database updated in 0.016898632049560547 seconds
#
# Rows fetched: 1282000	in 4.1663124561309814	seconds
# Dataframe and database updated in 0.0440828800201416 seconds
#
# Rows fetched: 1282250	in 2.4648122787475586	seconds
# Dataframe and database updated in 0.01627373695373535 seconds
#
# Rows fetched: 1282500	in 2.04815673828125	seconds
# Dataframe and database updated in 0.018451213836669922 seconds
#
# Rows fetched: 1282750	in 1.9365813732147217	seconds
# Dataframe and database updated in 0.01790142059326172 seconds
#
# Rows fetched: 1283000	in 2.208367109298706	seconds
# Dataframe and database updated in 0.016933917999267578 seconds
#
# Rows fetched: 1283250	in 1.923964023590088	seconds
# Dataframe and database updated in 0.02048325538635254 seconds
#
# Rows fetched: 1283500	in 1.852163553237915	seconds
# Dataframe and database updated in 0.01872396469116211 seconds
#
# Rows fetched: 1283750	in 2.4464383125305176	seconds
# Dataframe and database updated in 0.01656174659729004 seconds
#
# Rows fetched: 1284000	in 1.797790765762329	seconds
# Dataframe and database updated in 0.04636883735656738 seconds
#
# Rows fetched: 1284250	in 1.6046273708343506	seconds
# Dataframe and database updated in 0.01933431625366211 seconds
#
# Rows fetched: 1284500	in 2.061389923095703	seconds
# Dataframe and database updated in 0.01777958869934082 seconds
#
# Rows fetched: 1284750	in 1.9712345600128174	seconds
# Dataframe and database updated in 0.019428014755249023 seconds
#
# Rows fetched: 1285000	in 1.8758347034454346	seconds
# Dataframe and database updated in 0.019257545471191406 seconds
#
# Rows fetched: 1285250	in 2.4498424530029297	seconds
# Dataframe and database updated in 0.017452716827392578 seconds
#
# Rows fetched: 1285500	in 2.5850422382354736	seconds
# Dataframe and database updated in 0.018786907196044922 seconds
#
# Rows fetched: 1285750	in 4.005762815475464	seconds
# Dataframe and database updated in 0.02103257179260254 seconds
#
# Rows fetched: 1286000	in 7.500051975250244	seconds
# Dataframe and database updated in 0.020409822463989258 seconds
#
# Rows fetched: 1286250	in 1.5867083072662354	seconds
# Dataframe and database updated in 0.0441286563873291 seconds
#
# Rows fetched: 1286500	in 4.746701955795288	seconds
# Dataframe and database updated in 0.018340587615966797 seconds
#
# Rows fetched: 1286750	in 11.976344347000122	seconds
# Dataframe and database updated in 0.0193479061126709 seconds
#
# Rows fetched: 1287000	in 23.448901891708374	seconds
# Dataframe and database updated in 0.014657735824584961 seconds
#
# Rows fetched: 1287250	in 6.6837241649627686	seconds
# Dataframe and database updated in 0.016067981719970703 seconds
#
# Rows fetched: 1287500	in 4.341005802154541	seconds
# Dataframe and database updated in 0.019131183624267578 seconds
#
# Rows fetched: 1287750	in 25.220287799835205	seconds
# Dataframe and database updated in 0.018619060516357422 seconds
#
# Rows fetched: 1288000	in 28.39303970336914	seconds
# Dataframe and database updated in 0.01806640625 seconds
#
# Rows fetched: 1288250	in 24.65342092514038	seconds
# Dataframe and database updated in 0.017791271209716797 seconds
#
# Rows fetched: 1288500	in 16.127848148345947	seconds
# Dataframe and database updated in 0.029991626739501953 seconds
#
# Rows fetched: 1288750	in 20.460124015808105	seconds
# Dataframe and database updated in 0.019164323806762695 seconds
#
# Rows fetched: 1289000	in 57.19401407241821	seconds
# Dataframe and database updated in 0.017514944076538086 seconds
#
# Rows fetched: 1289250	in 83.53354692459106	seconds
# Dataframe and database updated in 0.020787954330444336 seconds
#
# Rows fetched: 1289500	in 58.65978264808655	seconds
# Dataframe and database updated in 0.01838231086730957 seconds
#
# Rows fetched: 1289750	in 57.34025502204895	seconds
# Dataframe and database updated in 0.019510746002197266 seconds
#
# Rows fetched: 1290000	in 13.977389812469482	seconds
# Dataframe and database updated in 0.01930069923400879 seconds
#
# Rows fetched: 1290250	in 86.42897605895996	seconds
# Dataframe and database updated in 0.01860332489013672 seconds
#
# Rows fetched: 1290500	in 17.148314714431763	seconds
# Dataframe and database updated in 0.027385473251342773 seconds
#
# Rows fetched: 1290750	in 6.910809516906738	seconds
# Dataframe and database updated in 0.018888473510742188 seconds
#
# Rows fetched: 1291000	in 4.156543731689453	seconds
# Dataframe and database updated in 0.019195556640625 seconds
#
# Rows fetched: 1291250	in 4.539094924926758	seconds
# Dataframe and database updated in 0.017852783203125 seconds
#
# Rows fetched: 1291500	in 3.7477385997772217	seconds
# Dataframe and database updated in 0.01668548583984375 seconds
#
# Rows fetched: 1291750	in 6.583848476409912	seconds
# Dataframe and database updated in 0.022151947021484375 seconds
#
# Rows fetched: 1292000	in 6.807743787765503	seconds
# Dataframe and database updated in 0.018991708755493164 seconds
#
# Rows fetched: 1292250	in 63.37487435340881	seconds
# Dataframe and database updated in 0.019554853439331055 seconds
#
# Rows fetched: 1292500	in 52.23505878448486	seconds
# Dataframe and database updated in 0.03490042686462402 seconds
#
# Rows fetched: 1292750	in 46.1677143573761	seconds
# Dataframe and database updated in 0.018257617950439453 seconds
#
# Rows fetched: 1293000	in 51.20135140419006	seconds
# Dataframe and database updated in 0.02202439308166504 seconds
#
# Rows fetched: 1293250	in 72.16202211380005	seconds
# Dataframe and database updated in 0.022120952606201172 seconds
#
# Rows fetched: 1293500	in 91.49699330329895	seconds
# Dataframe and database updated in 0.018292665481567383 seconds
#
# Rows fetched: 1293750	in 84.69028377532959	seconds
# Dataframe and database updated in 0.02094268798828125 seconds
#
# Rows fetched: 1294000	in 93.88331031799316	seconds
# Dataframe and database updated in 0.01736283302307129 seconds
#
# Rows fetched: 1294250	in 62.56885075569153	seconds
# Dataframe and database updated in 0.019185543060302734 seconds
#
# Rows fetched: 1294500	in 71.12610268592834	seconds
# Dataframe and database updated in 0.03369283676147461 seconds
#
# Rows fetched: 1294750	in 72.49202299118042	seconds
# Dataframe and database updated in 0.022385120391845703 seconds
#
# Rows fetched: 1295000	in 74.33483529090881	seconds
# Dataframe and database updated in 0.018034934997558594 seconds
#
# Rows fetched: 1295250	in 13.352328777313232	seconds
# Dataframe and database updated in 0.016542911529541016 seconds
#
# Rows fetched: 1295500	in 10.54721212387085	seconds
# Dataframe and database updated in 0.019007205963134766 seconds
#
# Rows fetched: 1295750	in 19.265129566192627	seconds
# Dataframe and database updated in 0.02095484733581543 seconds
#
# Rows fetched: 1296000	in 8.346532821655273	seconds
# Dataframe and database updated in 0.020833969116210938 seconds
#
# Rows fetched: 1296250	in 6.199816942214966	seconds
# Dataframe and database updated in 0.01971745491027832 seconds
#
# Rows fetched: 1296500	in 17.495137214660645	seconds
# Dataframe and database updated in 0.030815601348876953 seconds
#
# Rows fetched: 1296750	in 8.657888412475586	seconds
# Dataframe and database updated in 0.0187375545501709 seconds
#
# Rows fetched: 1297000	in 5.938226699829102	seconds
# Dataframe and database updated in 0.025298118591308594 seconds
#
# Rows fetched: 1297250	in 6.149588346481323	seconds
# Dataframe and database updated in 0.021370887756347656 seconds
#
# Rows fetched: 1297500	in 6.672091245651245	seconds
# Dataframe and database updated in 0.0192263126373291 seconds
#
# Rows fetched: 1297750	in 4.821066379547119	seconds
# Dataframe and database updated in 0.021405458450317383 seconds
#
# Rows fetched: 1298000	in 24.104347229003906	seconds
# Dataframe and database updated in 0.021295547485351562 seconds
#
# Rows fetched: 1298250	in 4.384405851364136	seconds
# Dataframe and database updated in 0.019559144973754883 seconds
#
# Rows fetched: 1298500	in 3.9876348972320557	seconds
# Dataframe and database updated in 0.020299911499023438 seconds
#
# Rows fetched: 1298750	in 5.557616710662842	seconds
# Dataframe and database updated in 0.03674173355102539 seconds
#
# Rows fetched: 1299000	in 4.145127773284912	seconds
# Dataframe and database updated in 0.018073081970214844 seconds
#
# Rows fetched: 1299250	in 3.884753465652466	seconds
# Dataframe and database updated in 0.01981520652770996 seconds
#
# Rows fetched: 1299500	in 24.756103992462158	seconds
# Dataframe and database updated in 0.01650261878967285 seconds
#
# Rows fetched: 1299750	in 42.032302141189575	seconds
# Dataframe and database updated in 0.020169973373413086 seconds
#
# Rows fetched: 1300000	in 23.022746801376343	seconds
# Dataframe and database updated in 0.018641233444213867 seconds
#
# Rows fetched: 1300250	in 16.216176986694336	seconds
# Dataframe and database updated in 0.02102065086364746 seconds
#
# Rows fetched: 1300500	in 41.259589433670044	seconds
# Dataframe and database updated in 0.019317150115966797 seconds
#
# Rows fetched: 1300750	in 37.96335291862488	seconds
# Dataframe and database updated in 0.027051210403442383 seconds
#
# Rows fetched: 1301000	in 31.00469446182251	seconds
# Dataframe and database updated in 0.015819787979125977 seconds
#
# Rows fetched: 1301250	in 6.051315069198608	seconds
# Dataframe and database updated in 0.01734018325805664 seconds
#
# Rows fetched: 1301500	in 9.375284194946289	seconds
# Dataframe and database updated in 0.021268367767333984 seconds
#
# Rows fetched: 1301750	in 15.085659742355347	seconds
# Dataframe and database updated in 0.018691062927246094 seconds
#
# Rows fetched: 1302000	in 53.050793170928955	seconds
# Dataframe and database updated in 0.017552852630615234 seconds
#
# Rows fetched: 1302250	in 72.14406943321228	seconds
# Dataframe and database updated in 0.016370296478271484 seconds
#
# Rows fetched: 1302500	in 18.157336235046387	seconds
# Dataframe and database updated in 0.019054174423217773 seconds
#
# Rows fetched: 1302750	in 17.79790234565735	seconds
# Dataframe and database updated in 0.0174405574798584 seconds
#
# Rows fetched: 1303000	in 39.099467754364014	seconds
# Dataframe and database updated in 0.0364835262298584 seconds
#
# Rows fetched: 1303250	in 60.56210207939148	seconds
# Dataframe and database updated in 0.020669221878051758 seconds
#
# Rows fetched: 1303500	in 53.21199655532837	seconds
# Dataframe and database updated in 0.020320653915405273 seconds
#
# Rows fetched: 1303750	in 50.44880390167236	seconds
# Dataframe and database updated in 0.01882195472717285 seconds
#
# Rows fetched: 1304000	in 15.333015441894531	seconds
# Dataframe and database updated in 0.014235973358154297 seconds
#
# Rows fetched: 1304250	in 27.842402935028076	seconds
# Dataframe and database updated in 0.017474651336669922 seconds
#
# Rows fetched: 1304500	in 31.013373851776123	seconds
# Dataframe and database updated in 0.0194089412689209 seconds
#
# Rows fetched: 1304750	in 37.14920210838318	seconds
# Dataframe and database updated in 0.0321347713470459 seconds
#
# Rows fetched: 1305000	in 40.68558168411255	seconds
# Dataframe and database updated in 0.01760387420654297 seconds
#
# Rows fetched: 1305250	in 33.03423738479614	seconds
# Dataframe and database updated in 0.02030801773071289 seconds
#
# Rows fetched: 1305500	in 49.94055771827698	seconds
# Dataframe and database updated in 0.018335342407226562 seconds
#
# Rows fetched: 1305750	in 13.14855432510376	seconds
# Dataframe and database updated in 0.01619434356689453 seconds
#
# Rows fetched: 1306000	in 4.756768703460693	seconds
# Dataframe and database updated in 0.017054080963134766 seconds
#
# Rows fetched: 1306250	in 4.921844244003296	seconds
# Dataframe and database updated in 0.01826024055480957 seconds
#
# Rows fetched: 1306500	in 4.173463582992554	seconds
# Dataframe and database updated in 0.020232677459716797 seconds
#
# Rows fetched: 1306750	in 4.067490339279175	seconds
# Dataframe and database updated in 0.018414735794067383 seconds
#
# Rows fetched: 1307000	in 5.5270373821258545	seconds
# Dataframe and database updated in 0.04699206352233887 seconds
#
# Rows fetched: 1307250	in 7.518630504608154	seconds
# Dataframe and database updated in 0.019601821899414062 seconds
#
# Rows fetched: 1307500	in 32.92047190666199	seconds
# Dataframe and database updated in 0.015396356582641602 seconds
#
# Rows fetched: 1307750	in 17.96027445793152	seconds
# Dataframe and database updated in 0.02165961265563965 seconds
#
# Rows fetched: 1308000	in 16.767254114151	seconds
# Dataframe and database updated in 0.022484302520751953 seconds
#
# Rows fetched: 1308250	in 16.344303846359253	seconds
# Dataframe and database updated in 0.019413232803344727 seconds
#
# Rows fetched: 1308500	in 36.09511399269104	seconds
# Dataframe and database updated in 0.01683783531188965 seconds
#
# Rows fetched: 1308750	in 15.417966842651367	seconds
# Dataframe and database updated in 0.016083478927612305 seconds
#
# Rows fetched: 1309000	in 35.059014558792114	seconds
# Dataframe and database updated in 0.026546001434326172 seconds
#
# Rows fetched: 1309250	in 36.39117503166199	seconds
# Dataframe and database updated in 0.020488739013671875 seconds
#
# Rows fetched: 1309500	in 60.7163622379303	seconds
# Dataframe and database updated in 0.018662691116333008 seconds
#
# Rows fetched: 1309750	in 58.07121205329895	seconds
# Dataframe and database updated in 0.019374608993530273 seconds
#
# Rows fetched: 1310000	in 80.80989265441895	seconds
# Dataframe and database updated in 0.02431488037109375 seconds
#
# Rows fetched: 1310250	in 36.84767985343933	seconds
# Dataframe and database updated in 0.019741058349609375 seconds
#
# Rows fetched: 1310500	in 17.747946977615356	seconds
# Dataframe and database updated in 0.017685413360595703 seconds
#
# Rows fetched: 1310750	in 94.67894649505615	seconds
# Dataframe and database updated in 0.018367767333984375 seconds
#
# Rows fetched: 1311000	in 17.16273808479309	seconds
# Dataframe and database updated in 0.028939008712768555 seconds
#
# Rows fetched: 1311250	in 5.6100451946258545	seconds
# Dataframe and database updated in 0.022459983825683594 seconds
#
# Rows fetched: 1311500	in 6.031873941421509	seconds
# Dataframe and database updated in 0.019577741622924805 seconds
#
# Rows fetched: 1311750	in 4.558466672897339	seconds
# Dataframe and database updated in 0.02097940444946289 seconds
#
# Rows fetched: 1312000	in 4.1869494915008545	seconds
# Dataframe and database updated in 0.018337726593017578 seconds
#
# Rows fetched: 1312250	in 4.247174024581909	seconds
# Dataframe and database updated in 0.022387981414794922 seconds
#
# Rows fetched: 1312500	in 3.3262147903442383	seconds
# Dataframe and database updated in 0.018892288208007812 seconds
#
# Rows fetched: 1312750	in 4.776707410812378	seconds
# Dataframe and database updated in 0.01801013946533203 seconds
#
# Rows fetched: 1313000	in 6.4580237865448	seconds
# Dataframe and database updated in 0.018038272857666016 seconds
#
# Rows fetched: 1313250	in 16.91585636138916	seconds
# Dataframe and database updated in 0.03256630897521973 seconds
#
# Rows fetched: 1313500	in 15.743256330490112	seconds
# Dataframe and database updated in 0.01775074005126953 seconds
#
# Rows fetched: 1313750	in 18.6872501373291	seconds
# Dataframe and database updated in 0.017440080642700195 seconds
#
# Rows fetched: 1314000	in 10.030887603759766	seconds
# Dataframe and database updated in 0.017864704132080078 seconds
#
# Rows fetched: 1314250	in 9.880796670913696	seconds
# Dataframe and database updated in 0.020760774612426758 seconds
#
# Rows fetched: 1314500	in 29.638166904449463	seconds
# Dataframe and database updated in 0.018085956573486328 seconds
#
# Rows fetched: 1314750	in 9.001562356948853	seconds
# Dataframe and database updated in 0.0189361572265625 seconds
#
# Rows fetched: 1315000	in 9.446675777435303	seconds
# Dataframe and database updated in 0.01456904411315918 seconds
#
# Rows fetched: 1315250	in 9.84168791770935	seconds
# Dataframe and database updated in 0.01805257797241211 seconds
#
# Rows fetched: 1315500	in 18.048527002334595	seconds
# Dataframe and database updated in 0.03233194351196289 seconds
#
# Rows fetched: 1315750	in 24.96637535095215	seconds
# Dataframe and database updated in 0.016677379608154297 seconds
#
# Rows fetched: 1316000	in 7.369806289672852	seconds
# Dataframe and database updated in 0.026833057403564453 seconds
#
# Rows fetched: 1316250	in 3.637479782104492	seconds
# Dataframe and database updated in 0.022970199584960938 seconds
#
# Rows fetched: 1316500	in 2.8915488719940186	seconds
# Dataframe and database updated in 0.021442890167236328 seconds
#
# Rows fetched: 1316750	in 3.1095476150512695	seconds
# Dataframe and database updated in 0.019916534423828125 seconds
#
# Rows fetched: 1317000	in 2.5481317043304443	seconds
# Dataframe and database updated in 0.017382144927978516 seconds
#
# Rows fetched: 1317250	in 7.855626821517944	seconds
# Dataframe and database updated in 0.01737833023071289 seconds
#
# Rows fetched: 1317500	in 8.842967987060547	seconds
# Dataframe and database updated in 0.017358064651489258 seconds
#
# Rows fetched: 1317750	in 10.58022665977478	seconds
# Dataframe and database updated in 0.03489351272583008 seconds
#
# Rows fetched: 1318000	in 11.35034966468811	seconds
# Dataframe and database updated in 0.02580547332763672 seconds
#
# Rows fetched: 1318250	in 3.5118775367736816	seconds
# Dataframe and database updated in 0.02062058448791504 seconds
#
# Rows fetched: 1318500	in 3.5982322692871094	seconds
# Dataframe and database updated in 0.01794123649597168 seconds
#
# Rows fetched: 1318750	in 3.135887384414673	seconds
# Dataframe and database updated in 0.01876068115234375 seconds
#
# Rows fetched: 1319000	in 3.2535207271575928	seconds
# Dataframe and database updated in 0.018505334854125977 seconds
#
# Rows fetched: 1319250	in 2.677276134490967	seconds
# Dataframe and database updated in 0.01825118064880371 seconds
#
# Rows fetched: 1319500	in 2.155287027359009	seconds
# Dataframe and database updated in 0.01766824722290039 seconds
#
# Rows fetched: 1319750	in 3.410884141921997	seconds
# Dataframe and database updated in 0.030925750732421875 seconds
#
# Rows fetched: 1320000	in 3.4840126037597656	seconds
# Dataframe and database updated in 0.020055294036865234 seconds
#
# Rows fetched: 1320250	in 2.4306676387786865	seconds
# Dataframe and database updated in 0.01928400993347168 seconds
#
# Rows fetched: 1320500	in 3.4775257110595703	seconds
# Dataframe and database updated in 0.021830081939697266 seconds
#
# Rows fetched: 1320750	in 2.1498122215270996	seconds
# Dataframe and database updated in 0.01742720603942871 seconds
#
# Rows fetched: 1321000	in 2.0130722522735596	seconds
# Dataframe and database updated in 0.02134227752685547 seconds
#
# Rows fetched: 1321250	in 2.2019431591033936	seconds
# Dataframe and database updated in 0.02950882911682129 seconds
#
# Rows fetched: 1321500	in 3.8164637088775635	seconds
# Dataframe and database updated in 0.020946502685546875 seconds
#
# Rows fetched: 1321750	in 8.18141484260559	seconds
# Dataframe and database updated in 0.02308177947998047 seconds
#
# Rows fetched: 1322000	in 7.88905668258667	seconds
# Dataframe and database updated in 0.032633066177368164 seconds
#
# Rows fetched: 1322250	in 8.556233644485474	seconds
# Dataframe and database updated in 0.019576311111450195 seconds
#
# Rows fetched: 1322500	in 5.188255310058594	seconds
# Dataframe and database updated in 0.02053070068359375 seconds
#
# Rows fetched: 1322750	in 3.4428892135620117	seconds
# Dataframe and database updated in 0.019565105438232422 seconds
#
# Rows fetched: 1323000	in 7.707696914672852	seconds
# Dataframe and database updated in 0.022946596145629883 seconds
#
# Rows fetched: 1323250	in 5.360764741897583	seconds
# Dataframe and database updated in 0.022078752517700195 seconds
#
# Rows fetched: 1323500	in 6.05823540687561	seconds
# Dataframe and database updated in 0.01704716682434082 seconds
#
# Rows fetched: 1323750	in 5.5618157386779785	seconds
# Dataframe and database updated in 0.01860809326171875 seconds
#
# Rows fetched: 1324000	in 8.87649130821228	seconds
# Dataframe and database updated in 0.0404658317565918 seconds
#
# Rows fetched: 1324250	in 7.229436874389648	seconds
# Dataframe and database updated in 0.019113540649414062 seconds
#
# Rows fetched: 1324500	in 4.3556694984436035	seconds
# Dataframe and database updated in 0.019253015518188477 seconds
#
# Rows fetched: 1324750	in 7.698981046676636	seconds
# Dataframe and database updated in 0.020455598831176758 seconds
#
# Rows fetched: 1325000	in 15.754308938980103	seconds
# Dataframe and database updated in 0.021638154983520508 seconds
#
# Rows fetched: 1325250	in 34.80119442939758	seconds
# Dataframe and database updated in 0.02101898193359375 seconds
#
# Rows fetched: 1325500	in 42.48210287094116	seconds
# Dataframe and database updated in 0.019220352172851562 seconds
#
# Rows fetched: 1325750	in 84.9237163066864	seconds
# Dataframe and database updated in 0.020591259002685547 seconds
#
# Rows fetched: 1326000	in 38.59715175628662	seconds
# Dataframe and database updated in 0.018033504486083984 seconds
#
# Rows fetched: 1326250	in 14.95193099975586	seconds
# Dataframe and database updated in 0.03725767135620117 seconds
#
# Rows fetched: 1326500	in 29.111597061157227	seconds
# Dataframe and database updated in 0.02033090591430664 seconds
#
# Rows fetched: 1326750	in 20.667815685272217	seconds
# Dataframe and database updated in 0.018335342407226562 seconds
#
# Rows fetched: 1327000	in 30.99041509628296	seconds
# Dataframe and database updated in 0.02093362808227539 seconds
#
# Rows fetched: 1327250	in 27.72481632232666	seconds
# Dataframe and database updated in 0.017061471939086914 seconds
#
# Rows fetched: 1327500	in 46.05250263214111	seconds
# Dataframe and database updated in 0.02541637420654297 seconds
#
# Rows fetched: 1327750	in 24.787235975265503	seconds
# Dataframe and database updated in 0.020241737365722656 seconds
#
# Rows fetched: 1328000	in 31.587097883224487	seconds
# Dataframe and database updated in 0.0203702449798584 seconds
#
# Rows fetched: 1328250	in 27.777811288833618	seconds
# Dataframe and database updated in 0.031141281127929688 seconds
#
# Rows fetched: 1328500	in 30.480340242385864	seconds
# Dataframe and database updated in 0.022014379501342773 seconds
#
# Rows fetched: 1328750	in 51.580530643463135	seconds
# Dataframe and database updated in 0.01880955696105957 seconds
#
# Rows fetched: 1329000	in 38.03468918800354	seconds
# Dataframe and database updated in 0.019670963287353516 seconds
#
# Rows fetched: 1329250	in 29.43526601791382	seconds
# Dataframe and database updated in 0.019154787063598633 seconds
#
# Rows fetched: 1329500	in 44.58329391479492	seconds
# Dataframe and database updated in 0.021430015563964844 seconds
#
# Rows fetched: 1329750	in 47.99668860435486	seconds
# Dataframe and database updated in 0.01992511749267578 seconds
#
# Rows fetched: 1330000	in 42.68028140068054	seconds
# Dataframe and database updated in 0.020223379135131836 seconds
#
# Rows fetched: 1330250	in 38.83283495903015	seconds
# Dataframe and database updated in 0.03179430961608887 seconds
#
# Rows fetched: 1330500	in 6.791502475738525	seconds
# Dataframe and database updated in 0.02262592315673828 seconds
#
# Rows fetched: 1330750	in 7.14919376373291	seconds
# Dataframe and database updated in 0.020599842071533203 seconds
#
# Rows fetched: 1331000	in 7.500125408172607	seconds
# Dataframe and database updated in 0.02198934555053711 seconds
#
# Rows fetched: 1331250	in 6.944829225540161	seconds
# Dataframe and database updated in 0.01784372329711914 seconds
#
# Rows fetched: 1331500	in 8.196639776229858	seconds
# Dataframe and database updated in 0.017867326736450195 seconds
#
# Rows fetched: 1331750	in 8.175289869308472	seconds
# Dataframe and database updated in 0.018346786499023438 seconds
#
# Rows fetched: 1332000	in 6.175647258758545	seconds
# Dataframe and database updated in 0.020145654678344727 seconds
#
# Rows fetched: 1332250	in 11.011273860931396	seconds
# Dataframe and database updated in 0.034105777740478516 seconds
#
# Rows fetched: 1332500	in 7.684206485748291	seconds
# Dataframe and database updated in 0.022330284118652344 seconds
#
# Rows fetched: 1332750	in 6.77418327331543	seconds
# Dataframe and database updated in 0.01823592185974121 seconds
#
# Rows fetched: 1333000	in 5.712943077087402	seconds
# Dataframe and database updated in 0.021963119506835938 seconds
#
# Rows fetched: 1333250	in 5.028017520904541	seconds
# Dataframe and database updated in 0.02145528793334961 seconds
#
# Rows fetched: 1333500	in 6.693403244018555	seconds
# Dataframe and database updated in 0.02103424072265625 seconds
#
# Rows fetched: 1333750	in 4.780932664871216	seconds
# Dataframe and database updated in 0.02022099494934082 seconds
#
# Rows fetched: 1334000	in 3.667776346206665	seconds
# Dataframe and database updated in 0.020609617233276367 seconds
#
# Rows fetched: 1334250	in 2.83011794090271	seconds
# Dataframe and database updated in 0.01824331283569336 seconds
#
# Rows fetched: 1334500	in 4.502838850021362	seconds
# Dataframe and database updated in 0.039353370666503906 seconds
#
# Rows fetched: 1334750	in 4.154312372207642	seconds
# Dataframe and database updated in 0.021181583404541016 seconds
#
# Rows fetched: 1335000	in 3.618565797805786	seconds
# Dataframe and database updated in 0.020644664764404297 seconds
#
# Rows fetched: 1335250	in 3.1608712673187256	seconds
# Dataframe and database updated in 0.020704984664916992 seconds
#
# Rows fetched: 1335500	in 2.902006149291992	seconds
# Dataframe and database updated in 0.0165865421295166 seconds
#
# Rows fetched: 1335750	in 3.520777463912964	seconds
# Dataframe and database updated in 0.01782369613647461 seconds
#
# Rows fetched: 1336000	in 3.6108598709106445	seconds
# Dataframe and database updated in 0.01978158950805664 seconds
#
# Rows fetched: 1336250	in 3.5418498516082764	seconds
# Dataframe and database updated in 0.025170564651489258 seconds
#
# Rows fetched: 1336500	in 2.5719332695007324	seconds
# Dataframe and database updated in 0.020865201950073242 seconds
#
# Rows fetched: 1336750	in 2.3771615028381348	seconds
# Dataframe and database updated in 0.0413055419921875 seconds
#
# Rows fetched: 1337000	in 2.226260185241699	seconds
# Dataframe and database updated in 0.020217418670654297 seconds
#
# Rows fetched: 1337250	in 6.449759006500244	seconds
# Dataframe and database updated in 0.017637014389038086 seconds
#
# Rows fetched: 1337500	in 6.077537536621094	seconds
# Dataframe and database updated in 0.020315885543823242 seconds
#
# Rows fetched: 1337750	in 5.567852020263672	seconds
# Dataframe and database updated in 0.02172231674194336 seconds
#
# Rows fetched: 1338000	in 7.656350135803223	seconds
# Dataframe and database updated in 0.02056598663330078 seconds
#
# Rows fetched: 1338250	in 8.128610372543335	seconds
# Dataframe and database updated in 0.018860816955566406 seconds
#
# Rows fetched: 1338500	in 4.586631774902344	seconds
# Dataframe and database updated in 0.02144002914428711 seconds
#
# Rows fetched: 1338750	in 4.852747678756714	seconds
# Dataframe and database updated in 0.018189430236816406 seconds
#
# Rows fetched: 1339000	in 6.731898069381714	seconds
# Dataframe and database updated in 0.044455766677856445 seconds
#
# Rows fetched: 1339250	in 3.526341676712036	seconds
# Dataframe and database updated in 0.019208192825317383 seconds
#
# Rows fetched: 1339500	in 2.990107536315918	seconds
# Dataframe and database updated in 0.01813197135925293 seconds
#
# Rows fetched: 1339750	in 4.526350021362305	seconds
# Dataframe and database updated in 0.023939132690429688 seconds
#
# Rows fetched: 1340000	in 4.518583059310913	seconds
# Dataframe and database updated in 0.022866487503051758 seconds
#
# Rows fetched: 1340250	in 3.650285482406616	seconds
# Dataframe and database updated in 0.02034616470336914 seconds
#
# Rows fetched: 1340500	in 5.713030099868774	seconds
# Dataframe and database updated in 0.01789402961730957 seconds
#
# Rows fetched: 1340750	in 14.725777864456177	seconds
# Dataframe and database updated in 0.023902177810668945 seconds
#
# Rows fetched: 1341000	in 10.702222108840942	seconds
# Dataframe and database updated in 0.03361701965332031 seconds
#
# Rows fetched: 1341250	in 10.378148794174194	seconds
# Dataframe and database updated in 0.022576570510864258 seconds

# %%
# closing the db connection
conn.close()
