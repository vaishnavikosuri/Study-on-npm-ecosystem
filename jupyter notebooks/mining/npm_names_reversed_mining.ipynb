# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import subprocess
import pandas as pd
import requests
from urllib.parse import urljoin
import sqlite3
import json
import time

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
os.chdir("/content/gdrive/Shareddrives/ECS 260")
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# # DB Init

# %%
# db init
# db_columns = ['package', 'id', 'key', 'value', 'meta_data']
# df = pd.DataFrame(columns=db_columns)

conn = sqlite3.connect('npm_names_rev.db')
cursor = conn.cursor()

# Create a table in the database
cursor.execute('''
    CREATE TABLE IF NOT EXISTS npm_package_names (
        package TEXT
    )
''')
conn.commit()

# %% [markdown]
# # Function Definitions and inits

# %%
def fetch_response_with_retry(url, limit, skip, startkey = '', max_retries=3):
    retry_count = 0

    while retry_count < max_retries:
        try:
            if not startkey == '':
              params = {
                  'limit': limit,
                  'skip': skip,
                  'startkey_docid': startkey,
                  'descending': 'true',
                  # 'include_docs': 'true'  # include package metadata in the response
              }
            else:
              params = {
                  'limit': limit,
                  'skip': skip,
                  'descending': 'true',
                  # 'include_docs': 'true'  # include package metadata in the response
              }

            response = requests.get(url, params=params)

            if response.status_code == 200:
                return response.json()
            else:
                print(f"Error: {response.status_code}")
                print(params)
                retry_count += 1
                print(f"Retrying in 5 seconds... (Retry {retry_count}/{max_retries})")
                time.sleep(5)

        except Exception as e:
            print(f"Exception occurred: {e}")
            retry_count += 1
            print(f"Retrying in 5 seconds... (Retry {retry_count}/{max_retries})")
            time.sleep(5)

    print(f"Max retries reached. Unable to fetch data from {url}.")
    return None

# %%
npm_base = "https://replicate.npmjs.com/"
all_endpoint = '_all_docs'
url = urljoin(npm_base, all_endpoint)

# %%
cursor.execute('SELECT COUNT(*) FROM npm_package_names')
rows_fetched = cursor.fetchone()[0]
print(f"Names mined so far: {rows_fetched}")
# Out:
# Names mined so far: 1273250

# %%
cursor.execute('''
    SELECT * FROM npm_package_names
    ORDER BY package
''')

last_row = cursor.fetchone()
last_row_key = last_row[0]
print(f"Last package mined --> {last_row_key}")
# Out:
# Last package mined --> fritzy

# %%
total_packages_available = 2682257
total_rows = total_packages_available/2
rows_per_page = 250

# %%
page_json_response = fetch_response_with_retry(url, rows_per_page, 0, last_row_key)

# %%
page_json_response["rows"][0]
# Out:
# {'id': 'fritzy',
#  'key': 'fritzy',
#  'value': {'rev': '3-14a90b516b342c03e6a1caa48c4f75b2'}}

# %% [markdown]
# # Mining

# %%
curr_offset = 1 if last_row_key else 0

if last_row_key:
  while rows_fetched < total_rows:
    api_call_start_time = time.time()


    page_json_response = fetch_response_with_retry(url, rows_per_page, curr_offset, last_row_key)


    api_call_end_time = time.time()
    elapsed_api_call_time = api_call_end_time - api_call_start_time

    db_update_start_time = time.time()

    if page_json_response:
      rows_fetched += rows_per_page


      print("Rows fetched: " + str(rows_fetched) + "\tin " + str(elapsed_api_call_time) + "\tseconds")
      curr_offset = 1
      last_row_key = page_json_response['rows'][-1]['key']

      packages = [(row['key'],) for row in page_json_response['rows']]
      # updating db
      cursor.executemany('''
              INSERT INTO npm_package_names (package)
              VALUES (?)
          ''', packages)
      conn.commit()

      db_update_end_time = time.time()
      elapsed_db_update_time = db_update_end_time - db_update_start_time
      print("Dataframe and database updated in " + str(elapsed_db_update_time) + " seconds")
      print()
# Out:
# Rows fetched: 1273500	in 15.546140432357788	seconds
# Dataframe and database updated in 0.02107834815979004 seconds
#
# Rows fetched: 1273750	in 13.182391166687012	seconds
# Dataframe and database updated in 0.020333290100097656 seconds
#
# Rows fetched: 1274000	in 19.81485867500305	seconds
# Dataframe and database updated in 0.018155336380004883 seconds
#
# Rows fetched: 1274250	in 16.590994596481323	seconds
# Dataframe and database updated in 0.01592278480529785 seconds
#
# Rows fetched: 1274500	in 11.68268609046936	seconds
# Dataframe and database updated in 0.03165793418884277 seconds
#
# Rows fetched: 1274750	in 27.864516258239746	seconds
# Dataframe and database updated in 0.02157735824584961 seconds
#
# Rows fetched: 1275000	in 15.32732892036438	seconds
# Dataframe and database updated in 0.017379045486450195 seconds
#
# Rows fetched: 1275250	in 9.135756969451904	seconds
# Dataframe and database updated in 0.0164639949798584 seconds
#
# Rows fetched: 1275500	in 5.309165000915527	seconds
# Dataframe and database updated in 0.017346620559692383 seconds
#
# Rows fetched: 1275750	in 3.7696354389190674	seconds
# Dataframe and database updated in 0.017116308212280273 seconds
#
# Rows fetched: 1276000	in 3.98616886138916	seconds
# Dataframe and database updated in 0.016286611557006836 seconds
#
# Rows fetched: 1276250	in 7.011478900909424	seconds
# Dataframe and database updated in 0.017387866973876953 seconds
#
# Rows fetched: 1276500	in 7.51352071762085	seconds
# Dataframe and database updated in 0.020211219787597656 seconds
#
# Rows fetched: 1276750	in 7.84137487411499	seconds
# Dataframe and database updated in 0.034948110580444336 seconds
#
# Rows fetched: 1277000	in 4.208552122116089	seconds
# Dataframe and database updated in 0.01685047149658203 seconds
#
# Rows fetched: 1277250	in 8.320531129837036	seconds
# Dataframe and database updated in 0.018111705780029297 seconds
#
# Rows fetched: 1277500	in 9.661997556686401	seconds
# Dataframe and database updated in 0.01710677146911621 seconds
#
# Rows fetched: 1277750	in 5.281958341598511	seconds
# Dataframe and database updated in 0.01790142059326172 seconds
#
# Rows fetched: 1278000	in 6.6880857944488525	seconds
# Dataframe and database updated in 0.015900850296020508 seconds
#
# Rows fetched: 1278250	in 3.3430027961730957	seconds
# Dataframe and database updated in 0.016232728958129883 seconds
#
# Rows fetched: 1278500	in 4.990588426589966	seconds
# Dataframe and database updated in 0.016436100006103516 seconds
#
# Rows fetched: 1278750	in 6.751063108444214	seconds
# Dataframe and database updated in 0.020667076110839844 seconds
#
# Rows fetched: 1279000	in 3.4978573322296143	seconds
# Dataframe and database updated in 0.03869462013244629 seconds
#
# Rows fetched: 1279250	in 5.428406238555908	seconds
# Dataframe and database updated in 0.020354270935058594 seconds
#
# Rows fetched: 1279500	in 5.704717636108398	seconds
# Dataframe and database updated in 0.014926910400390625 seconds
#
# Rows fetched: 1279750	in 5.872881650924683	seconds
# Dataframe and database updated in 0.016162395477294922 seconds
#
# Rows fetched: 1280000	in 7.507792711257935	seconds
# Dataframe and database updated in 0.015848398208618164 seconds
#
# Rows fetched: 1280250	in 2.873617649078369	seconds
# Dataframe and database updated in 0.01702094078063965 seconds
#
# Rows fetched: 1280500	in 2.1540136337280273	seconds
# Dataframe and database updated in 0.01837897300720215 seconds
#
# Rows fetched: 1280750	in 3.252389669418335	seconds
# Dataframe and database updated in 0.016555070877075195 seconds
#
# Rows fetched: 1281000	in 7.675681114196777	seconds
# Dataframe and database updated in 0.016841888427734375 seconds
#
# Rows fetched: 1281250	in 9.471207857131958	seconds
# Dataframe and database updated in 0.037453651428222656 seconds
#
# Rows fetched: 1281500	in 9.918092727661133	seconds
# Dataframe and database updated in 0.015430688858032227 seconds
#
# Rows fetched: 1281750	in 9.584735870361328	seconds
# Dataframe and database updated in 0.015524148941040039 seconds
#
# Rows fetched: 1282000	in 4.4433417320251465	seconds
# Dataframe and database updated in 0.020828962326049805 seconds
#
# Rows fetched: 1282250	in 4.52952241897583	seconds
# Dataframe and database updated in 0.01872873306274414 seconds
#
# Rows fetched: 1282500	in 18.997214794158936	seconds
# Dataframe and database updated in 0.018580198287963867 seconds
#
# Rows fetched: 1282750	in 9.155326843261719	seconds
# Dataframe and database updated in 0.019219636917114258 seconds
#
# Rows fetched: 1283000	in 6.372809171676636	seconds
# Dataframe and database updated in 0.016152620315551758 seconds
#
# Rows fetched: 1283250	in 7.8684282302856445	seconds
# Dataframe and database updated in 0.039481163024902344 seconds
#
# Rows fetched: 1283500	in 6.8209381103515625	seconds
# Dataframe and database updated in 0.018691539764404297 seconds
#
# Rows fetched: 1283750	in 6.250949382781982	seconds
# Dataframe and database updated in 0.018019914627075195 seconds
#
# Rows fetched: 1284000	in 4.164682388305664	seconds
# Dataframe and database updated in 0.017170429229736328 seconds
#
# Rows fetched: 1284250	in 3.6569156646728516	seconds
# Dataframe and database updated in 0.017131567001342773 seconds
#
# Rows fetched: 1284500	in 10.960174083709717	seconds
# Dataframe and database updated in 0.018404722213745117 seconds
#
# Rows fetched: 1284750	in 13.068175315856934	seconds
# Dataframe and database updated in 0.016524076461791992 seconds
#
# Rows fetched: 1285000	in 9.63734483718872	seconds
# Dataframe and database updated in 0.021987199783325195 seconds
#
# Rows fetched: 1285250	in 26.64768075942993	seconds
# Dataframe and database updated in 0.017591238021850586 seconds
#
# Rows fetched: 1285500	in 4.870266914367676	seconds
# Dataframe and database updated in 0.021135807037353516 seconds
#
# Rows fetched: 1285750	in 4.345844268798828	seconds
# Dataframe and database updated in 0.017584800720214844 seconds
#
# Rows fetched: 1286000	in 7.41776180267334	seconds
# Dataframe and database updated in 0.021668672561645508 seconds
#
# Rows fetched: 1286250	in 6.520298004150391	seconds
# Dataframe and database updated in 0.016837596893310547 seconds
#
# Rows fetched: 1286500	in 6.493560314178467	seconds
# Dataframe and database updated in 0.01903247833251953 seconds
#
# Rows fetched: 1286750	in 6.219296216964722	seconds
# Dataframe and database updated in 0.01690673828125 seconds
#
# Rows fetched: 1287000	in 3.8413479328155518	seconds
# Dataframe and database updated in 0.019937753677368164 seconds
#
# Rows fetched: 1287250	in 3.4927818775177	seconds
# Dataframe and database updated in 0.02120065689086914 seconds
#
# Rows fetched: 1287500	in 3.0607192516326904	seconds
# Dataframe and database updated in 0.022162437438964844 seconds
#
# Rows fetched: 1287750	in 4.258877277374268	seconds
# Dataframe and database updated in 0.039754629135131836 seconds
#
# Rows fetched: 1288000	in 4.801372289657593	seconds
# Dataframe and database updated in 0.023338794708251953 seconds
#
# Rows fetched: 1288250	in 4.137270212173462	seconds
# Dataframe and database updated in 0.017833709716796875 seconds
#
# Rows fetched: 1288500	in 6.424973487854004	seconds
# Dataframe and database updated in 0.02110123634338379 seconds
#
# Rows fetched: 1288750	in 5.336025714874268	seconds
# Dataframe and database updated in 0.018143177032470703 seconds
#
# Rows fetched: 1289000	in 9.604323387145996	seconds
# Dataframe and database updated in 0.020172834396362305 seconds
#
# Rows fetched: 1289250	in 6.152932643890381	seconds
# Dataframe and database updated in 0.017069339752197266 seconds
#
# Rows fetched: 1289500	in 6.498729228973389	seconds
# Dataframe and database updated in 0.022630691528320312 seconds
#
# Rows fetched: 1289750	in 17.43015170097351	seconds
# Dataframe and database updated in 0.019369840621948242 seconds
#
# Rows fetched: 1290000	in 4.636093616485596	seconds
# Dataframe and database updated in 0.03304028511047363 seconds
#
# Rows fetched: 1290250	in 16.08410882949829	seconds
# Dataframe and database updated in 0.019158601760864258 seconds
#
# Rows fetched: 1290500	in 5.351745843887329	seconds
# Dataframe and database updated in 0.020390748977661133 seconds
#
# Rows fetched: 1290750	in 5.722303628921509	seconds
# Dataframe and database updated in 0.018209457397460938 seconds
#
# Rows fetched: 1291000	in 8.50151515007019	seconds
# Dataframe and database updated in 0.019287824630737305 seconds
#
# Rows fetched: 1291250	in 5.77285099029541	seconds
# Dataframe and database updated in 0.01704573631286621 seconds
#
# Rows fetched: 1291500	in 4.61163330078125	seconds
# Dataframe and database updated in 0.020682811737060547 seconds
#
# Rows fetched: 1291750	in 7.656167268753052	seconds
# Dataframe and database updated in 0.022172212600708008 seconds
#
# Rows fetched: 1292000	in 4.2611424922943115	seconds
# Dataframe and database updated in 0.017615795135498047 seconds
#
# Rows fetched: 1292250	in 5.633416414260864	seconds
# Dataframe and database updated in 0.0386347770690918 seconds
#
# Rows fetched: 1292500	in 19.701894283294678	seconds
# Dataframe and database updated in 0.015110492706298828 seconds
#
# Rows fetched: 1292750	in 13.941606044769287	seconds
# Dataframe and database updated in 0.01791977882385254 seconds
#
# Rows fetched: 1293000	in 11.810579061508179	seconds
# Dataframe and database updated in 0.0189974308013916 seconds
#
# Rows fetched: 1293250	in 13.326429605484009	seconds
# Dataframe and database updated in 0.0180509090423584 seconds
#
# Rows fetched: 1293500	in 7.767261266708374	seconds
# Dataframe and database updated in 0.018613576889038086 seconds
#
# Rows fetched: 1293750	in 5.461493492126465	seconds
# Dataframe and database updated in 0.0178067684173584 seconds
#
# Rows fetched: 1294000	in 5.136419057846069	seconds
# Dataframe and database updated in 0.016124725341796875 seconds
#
# Rows fetched: 1294250	in 10.854953050613403	seconds
# Dataframe and database updated in 0.020786046981811523 seconds
#
# Rows fetched: 1294500	in 2.833899974822998	seconds
# Dataframe and database updated in 0.03017282485961914 seconds
#
# Rows fetched: 1294750	in 2.579110622406006	seconds
# Dataframe and database updated in 0.01983642578125 seconds
#
# Rows fetched: 1295000	in 2.5840728282928467	seconds
# Dataframe and database updated in 0.0201723575592041 seconds
#
# Rows fetched: 1295250	in 11.785975456237793	seconds
# Dataframe and database updated in 0.02131056785583496 seconds
#
# Rows fetched: 1295500	in 13.845823764801025	seconds
# Dataframe and database updated in 0.01818704605102539 seconds
#
# Rows fetched: 1295750	in 9.767853498458862	seconds
# Dataframe and database updated in 0.01924443244934082 seconds
#
# Rows fetched: 1296000	in 17.181313276290894	seconds
# Dataframe and database updated in 0.016315937042236328 seconds
#
# Rows fetched: 1296250	in 4.042803049087524	seconds
# Dataframe and database updated in 0.017678260803222656 seconds
#
# Rows fetched: 1296500	in 3.318051338195801	seconds
# Dataframe and database updated in 0.03898143768310547 seconds
#
# Rows fetched: 1296750	in 9.353724002838135	seconds
# Dataframe and database updated in 0.016831398010253906 seconds
#
# Rows fetched: 1297000	in 3.486100435256958	seconds
# Dataframe and database updated in 0.015791893005371094 seconds
#
# Rows fetched: 1297250	in 3.045370101928711	seconds
# Dataframe and database updated in 0.020863056182861328 seconds
#
# Rows fetched: 1297500	in 7.1727211475372314	seconds
# Dataframe and database updated in 0.019350051879882812 seconds
#
# Rows fetched: 1297750	in 10.766125679016113	seconds
# Dataframe and database updated in 0.01690363883972168 seconds
#
# Rows fetched: 1298000	in 9.877042055130005	seconds
# Dataframe and database updated in 0.01786637306213379 seconds
#
# Rows fetched: 1298250	in 11.441477537155151	seconds
# Dataframe and database updated in 0.020180463790893555 seconds
#
# Rows fetched: 1298500	in 3.703763484954834	seconds
# Dataframe and database updated in 0.019741296768188477 seconds
#
# Rows fetched: 1298750	in 1.7869338989257812	seconds
# Dataframe and database updated in 0.02865314483642578 seconds
#
# Rows fetched: 1299000	in 1.845128059387207	seconds
# Dataframe and database updated in 0.01915454864501953 seconds
#
# Rows fetched: 1299250	in 2.346586227416992	seconds
# Dataframe and database updated in 0.015268087387084961 seconds
#
# Rows fetched: 1299500	in 3.167295217514038	seconds
# Dataframe and database updated in 0.021389007568359375 seconds
#
# Rows fetched: 1299750	in 3.4427595138549805	seconds
# Dataframe and database updated in 0.018932342529296875 seconds
#
# Rows fetched: 1300000	in 2.389302968978882	seconds
# Dataframe and database updated in 0.017294645309448242 seconds
#
# Rows fetched: 1300250	in 2.1005330085754395	seconds
# Dataframe and database updated in 0.017115354537963867 seconds
#
# Rows fetched: 1300500	in 3.808723211288452	seconds
# Dataframe and database updated in 0.023280620574951172 seconds
#
# Rows fetched: 1300750	in 3.8979547023773193	seconds
# Dataframe and database updated in 0.018486499786376953 seconds
#
# Rows fetched: 1301000	in 3.0886025428771973	seconds
# Dataframe and database updated in 0.03548097610473633 seconds
#
# Rows fetched: 1301250	in 4.6026482582092285	seconds
# Dataframe and database updated in 0.019961833953857422 seconds
#
# Rows fetched: 1301500	in 2.763092517852783	seconds
# Dataframe and database updated in 0.015831470489501953 seconds
#
# Rows fetched: 1301750	in 3.0792317390441895	seconds
# Dataframe and database updated in 0.021351099014282227 seconds
#
# Rows fetched: 1302000	in 3.553837537765503	seconds
# Dataframe and database updated in 0.017720937728881836 seconds
#
# Rows fetched: 1302250	in 1.9782514572143555	seconds
# Dataframe and database updated in 0.016056060791015625 seconds
#
# Rows fetched: 1302500	in 2.26225209236145	seconds
# Dataframe and database updated in 0.01768660545349121 seconds
#
# Rows fetched: 1302750	in 2.725752592086792	seconds
# Dataframe and database updated in 0.02107548713684082 seconds
#
# Rows fetched: 1303000	in 3.6953649520874023	seconds
# Dataframe and database updated in 0.022189617156982422 seconds
#
# Rows fetched: 1303250	in 3.695024251937866	seconds
# Dataframe and database updated in 0.03515434265136719 seconds
#
# Rows fetched: 1303500	in 2.5455238819122314	seconds
# Dataframe and database updated in 0.017838716506958008 seconds
#
# Rows fetched: 1303750	in 3.0704803466796875	seconds
# Dataframe and database updated in 0.01972365379333496 seconds
#
# Rows fetched: 1304000	in 5.808516263961792	seconds
# Dataframe and database updated in 0.016171932220458984 seconds
#
# Rows fetched: 1304250	in 3.4217875003814697	seconds
# Dataframe and database updated in 0.02056145668029785 seconds
#
# Rows fetched: 1304500	in 6.681168556213379	seconds
# Dataframe and database updated in 0.015091419219970703 seconds
#
# Rows fetched: 1304750	in 5.718344211578369	seconds
# Dataframe and database updated in 0.018380403518676758 seconds
#
# Rows fetched: 1305000	in 5.798934698104858	seconds
# Dataframe and database updated in 0.01669931411743164 seconds
#
# Rows fetched: 1305250	in 5.843870162963867	seconds
# Dataframe and database updated in 0.03707408905029297 seconds
#
# Rows fetched: 1305500	in 10.749536752700806	seconds
# Dataframe and database updated in 0.01892685890197754 seconds
#
# Rows fetched: 1305750	in 6.084951639175415	seconds
# Dataframe and database updated in 0.01611948013305664 seconds
#
# Rows fetched: 1306000	in 3.907742738723755	seconds
# Dataframe and database updated in 0.01762533187866211 seconds
#
# Rows fetched: 1306250	in 3.0827102661132812	seconds
# Dataframe and database updated in 0.01666569709777832 seconds
#
# Rows fetched: 1306500	in 6.462226390838623	seconds
# Dataframe and database updated in 0.01842331886291504 seconds
#
# Rows fetched: 1306750	in 3.45149302482605	seconds
# Dataframe and database updated in 0.017136096954345703 seconds
#
# Rows fetched: 1307000	in 2.67267107963562	seconds
# Dataframe and database updated in 0.01230311393737793 seconds
#
# Rows fetched: 1307250	in 4.317613363265991	seconds
# Dataframe and database updated in 0.017862558364868164 seconds
#
# Rows fetched: 1307500	in 2.4336228370666504	seconds
# Dataframe and database updated in 0.0344843864440918 seconds
#
# Rows fetched: 1307750	in 2.687117576599121	seconds
# Dataframe and database updated in 0.02234363555908203 seconds
#
# Rows fetched: 1308000	in 1.941298007965088	seconds
# Dataframe and database updated in 0.016564369201660156 seconds
#
# Rows fetched: 1308250	in 3.9370884895324707	seconds
# Dataframe and database updated in 0.017306089401245117 seconds
#
# Rows fetched: 1308500	in 2.431753396987915	seconds
# Dataframe and database updated in 0.015619039535522461 seconds
#
# Rows fetched: 1308750	in 2.782073497772217	seconds
# Dataframe and database updated in 0.01743459701538086 seconds
#
# Rows fetched: 1309000	in 2.2735466957092285	seconds
# Dataframe and database updated in 0.018017053604125977 seconds
#
# Rows fetched: 1309250	in 2.2677557468414307	seconds
# Dataframe and database updated in 0.01699662208557129 seconds
#
# Rows fetched: 1309500	in 2.376687526702881	seconds
# Dataframe and database updated in 0.018140792846679688 seconds
#
# Rows fetched: 1309750	in 3.3928234577178955	seconds
# Dataframe and database updated in 0.04174399375915527 seconds
#
# Rows fetched: 1310000	in 3.092311143875122	seconds
# Dataframe and database updated in 0.018054723739624023 seconds
#
# Rows fetched: 1310250	in 3.71109938621521	seconds
# Dataframe and database updated in 0.016349077224731445 seconds
#
# Rows fetched: 1310500	in 4.405327558517456	seconds
# Dataframe and database updated in 0.019681215286254883 seconds
#
# Rows fetched: 1310750	in 2.651224136352539	seconds
# Dataframe and database updated in 0.01626729965209961 seconds
#
# Rows fetched: 1311000	in 3.1354024410247803	seconds
# Dataframe and database updated in 0.016672134399414062 seconds
#
# Rows fetched: 1311250	in 3.375431537628174	seconds
# Dataframe and database updated in 0.019422292709350586 seconds
#
# Rows fetched: 1311500	in 2.273967742919922	seconds
# Dataframe and database updated in 0.019073963165283203 seconds
#
# Rows fetched: 1311750	in 3.4869136810302734	seconds
# Dataframe and database updated in 0.01792120933532715 seconds
#
# Rows fetched: 1312000	in 2.9222447872161865	seconds
# Dataframe and database updated in 0.031105756759643555 seconds
#
# Rows fetched: 1312250	in 3.4939470291137695	seconds
# Dataframe and database updated in 0.01760125160217285 seconds
#
# Rows fetched: 1312500	in 5.652522325515747	seconds
# Dataframe and database updated in 0.0223081111907959 seconds
#
# Rows fetched: 1312750	in 3.7520594596862793	seconds
# Dataframe and database updated in 0.018836259841918945 seconds
#
# Rows fetched: 1313000	in 4.594931364059448	seconds
# Dataframe and database updated in 0.020641565322875977 seconds
#
# Rows fetched: 1313250	in 5.09500527381897	seconds
# Dataframe and database updated in 0.016587495803833008 seconds
#
# Rows fetched: 1313500	in 1.7634499073028564	seconds
# Dataframe and database updated in 0.020192623138427734 seconds
#
# Rows fetched: 1313750	in 2.091385841369629	seconds
# Dataframe and database updated in 0.020676851272583008 seconds
#
# Rows fetched: 1314000	in 1.9616975784301758	seconds
# Dataframe and database updated in 0.019834041595458984 seconds
#
# Rows fetched: 1314250	in 5.623623609542847	seconds
# Dataframe and database updated in 0.032232046127319336 seconds
#
# Rows fetched: 1314500	in 8.403750896453857	seconds
# Dataframe and database updated in 0.0160672664642334 seconds
#
# Rows fetched: 1314750	in 2.66402268409729	seconds
# Dataframe and database updated in 0.02598881721496582 seconds
#
# Rows fetched: 1315000	in 4.946954011917114	seconds
# Dataframe and database updated in 0.015022039413452148 seconds
#
# Rows fetched: 1315250	in 13.18730092048645	seconds
# Dataframe and database updated in 0.016638755798339844 seconds
#
# Rows fetched: 1315500	in 3.351574659347534	seconds
# Dataframe and database updated in 0.016786575317382812 seconds
#
# Rows fetched: 1315750	in 6.011443138122559	seconds
# Dataframe and database updated in 0.017111539840698242 seconds
#
# Rows fetched: 1316000	in 4.492102861404419	seconds
# Dataframe and database updated in 0.01831197738647461 seconds
#
# Rows fetched: 1316250	in 4.748331069946289	seconds
# Dataframe and database updated in 0.042000770568847656 seconds
#
# Rows fetched: 1316500	in 2.5919013023376465	seconds
# Dataframe and database updated in 0.017210006713867188 seconds
#
# Rows fetched: 1316750	in 6.761239290237427	seconds
# Dataframe and database updated in 0.017181873321533203 seconds
#
# Rows fetched: 1317000	in 6.721794605255127	seconds
# Dataframe and database updated in 0.01817178726196289 seconds
#
# Rows fetched: 1317250	in 3.7519633769989014	seconds
# Dataframe and database updated in 0.01627826690673828 seconds
#
# Rows fetched: 1317500	in 3.7974300384521484	seconds
# Dataframe and database updated in 0.02123737335205078 seconds
#
# Rows fetched: 1317750	in 1.6337730884552002	seconds
# Dataframe and database updated in 0.01998305320739746 seconds
#
# Rows fetched: 1318000	in 2.189317226409912	seconds
# Dataframe and database updated in 0.01975250244140625 seconds
#
# Rows fetched: 1318250	in 1.299407958984375	seconds
# Dataframe and database updated in 0.020148754119873047 seconds
#
# Rows fetched: 1318500	in 2.0851857662200928	seconds
# Dataframe and database updated in 0.056052446365356445 seconds
#
# Rows fetched: 1318750	in 2.1030845642089844	seconds
# Dataframe and database updated in 0.020336151123046875 seconds
#
# Rows fetched: 1319000	in 1.79768967628479	seconds
# Dataframe and database updated in 0.021229267120361328 seconds
#
# Rows fetched: 1319250	in 2.8678839206695557	seconds
# Dataframe and database updated in 0.01616382598876953 seconds
#
# Rows fetched: 1319500	in 1.5713703632354736	seconds
# Dataframe and database updated in 0.017374753952026367 seconds
#
# Rows fetched: 1319750	in 2.028507709503174	seconds
# Dataframe and database updated in 0.021288156509399414 seconds
#
# Rows fetched: 1320000	in 2.0829710960388184	seconds
# Dataframe and database updated in 0.018739938735961914 seconds
#
# Rows fetched: 1320250	in 1.6656968593597412	seconds
# Dataframe and database updated in 0.017352581024169922 seconds
#
# Rows fetched: 1320500	in 1.945392370223999	seconds
# Dataframe and database updated in 0.0195615291595459 seconds
#
# Rows fetched: 1320750	in 3.2248613834381104	seconds
# Dataframe and database updated in 0.04930686950683594 seconds
#
# Rows fetched: 1321000	in 3.9803671836853027	seconds
# Dataframe and database updated in 0.015014171600341797 seconds
#
# Rows fetched: 1321250	in 2.4187424182891846	seconds
# Dataframe and database updated in 0.017551898956298828 seconds
#
# Rows fetched: 1321500	in 4.3074517250061035	seconds
# Dataframe and database updated in 0.01893782615661621 seconds
#
# Rows fetched: 1321750	in 1.9999220371246338	seconds
# Dataframe and database updated in 0.02253246307373047 seconds
#
# Rows fetched: 1322000	in 2.1760172843933105	seconds
# Dataframe and database updated in 0.02262592315673828 seconds
#
# Rows fetched: 1322250	in 2.7627148628234863	seconds
# Dataframe and database updated in 0.015544414520263672 seconds
#
# Rows fetched: 1322500	in 1.8589379787445068	seconds
# Dataframe and database updated in 0.0208590030670166 seconds
#
# Rows fetched: 1322750	in 2.676750659942627	seconds
# Dataframe and database updated in 0.018856048583984375 seconds
#
# Rows fetched: 1323000	in 3.101637840270996	seconds
# Dataframe and database updated in 0.04078173637390137 seconds
#
# Rows fetched: 1323250	in 3.506141185760498	seconds
# Dataframe and database updated in 0.022297143936157227 seconds
#
# Rows fetched: 1323500	in 4.573949337005615	seconds
# Dataframe and database updated in 0.022890090942382812 seconds
#
# Rows fetched: 1323750	in 3.8296701908111572	seconds
# Dataframe and database updated in 0.01857924461364746 seconds
#
# Rows fetched: 1324000	in 4.616520166397095	seconds
# Dataframe and database updated in 0.02044391632080078 seconds
#
# Rows fetched: 1324250	in 4.62514066696167	seconds
# Dataframe and database updated in 0.020251035690307617 seconds
#
# Rows fetched: 1324500	in 6.882542133331299	seconds
# Dataframe and database updated in 0.0176236629486084 seconds
#
# Rows fetched: 1324750	in 3.022043228149414	seconds
# Dataframe and database updated in 0.01714801788330078 seconds
#
# Rows fetched: 1325000	in 2.3996479511260986	seconds
# Dataframe and database updated in 0.026363849639892578 seconds
#
# Rows fetched: 1325250	in 2.2256836891174316	seconds
# Dataframe and database updated in 0.03914690017700195 seconds
#
# Rows fetched: 1325500	in 2.600508213043213	seconds
# Dataframe and database updated in 0.016559839248657227 seconds
#
# Rows fetched: 1325750	in 1.8758842945098877	seconds
# Dataframe and database updated in 0.016860008239746094 seconds
#
# Rows fetched: 1326000	in 1.7214899063110352	seconds
# Dataframe and database updated in 0.01877593994140625 seconds
#
# Rows fetched: 1326250	in 1.5095434188842773	seconds
# Dataframe and database updated in 0.02468132972717285 seconds
#
# Rows fetched: 1326500	in 2.406649589538574	seconds
# Dataframe and database updated in 0.017946481704711914 seconds
#
# Rows fetched: 1326750	in 8.826810359954834	seconds
# Dataframe and database updated in 0.018979310989379883 seconds
#
# Rows fetched: 1327000	in 11.499650955200195	seconds
# Dataframe and database updated in 0.0238344669342041 seconds
#
# Rows fetched: 1327250	in 4.738960266113281	seconds
# Dataframe and database updated in 0.0189816951751709 seconds
#
# Rows fetched: 1327500	in 2.4680676460266113	seconds
# Dataframe and database updated in 0.04199099540710449 seconds
#
# Rows fetched: 1327750	in 9.551241397857666	seconds
# Dataframe and database updated in 0.017689943313598633 seconds
#
# Rows fetched: 1328000	in 5.735417604446411	seconds
# Dataframe and database updated in 0.016872644424438477 seconds
#
# Rows fetched: 1328250	in 6.297548532485962	seconds
# Dataframe and database updated in 0.018347501754760742 seconds
#
# Rows fetched: 1328500	in 5.061927795410156	seconds
# Dataframe and database updated in 0.02071213722229004 seconds
#
# Rows fetched: 1328750	in 7.195098876953125	seconds
# Dataframe and database updated in 0.016958236694335938 seconds
#
# Rows fetched: 1329000	in 6.791457653045654	seconds
# Dataframe and database updated in 0.01891636848449707 seconds
#
# Rows fetched: 1329250	in 4.882074356079102	seconds
# Dataframe and database updated in 0.01698017120361328 seconds
#
# Rows fetched: 1329500	in 3.4107613563537598	seconds
# Dataframe and database updated in 0.0460810661315918 seconds
#
# Rows fetched: 1329750	in 3.899895429611206	seconds
# Dataframe and database updated in 0.021327972412109375 seconds
#
# Rows fetched: 1330000	in 3.978781223297119	seconds
# Dataframe and database updated in 0.017446041107177734 seconds
#
# Rows fetched: 1330250	in 4.277383089065552	seconds
# Dataframe and database updated in 0.015783071517944336 seconds
#
# Rows fetched: 1330500	in 2.598123550415039	seconds
# Dataframe and database updated in 0.018141984939575195 seconds
#
# Rows fetched: 1330750	in 4.250119686126709	seconds
# Dataframe and database updated in 0.018830299377441406 seconds
#
# Rows fetched: 1331000	in 5.8523008823394775	seconds
# Dataframe and database updated in 0.016760826110839844 seconds
#
# Rows fetched: 1331250	in 4.723083972930908	seconds
# Dataframe and database updated in 0.016839981079101562 seconds
#
# Rows fetched: 1331500	in 5.673536539077759	seconds
# Dataframe and database updated in 0.02090764045715332 seconds
#
# Rows fetched: 1331750	in 4.573194980621338	seconds
# Dataframe and database updated in 0.028578758239746094 seconds
#
# Rows fetched: 1332000	in 3.6126925945281982	seconds
# Dataframe and database updated in 0.020512819290161133 seconds
#
# Rows fetched: 1332250	in 2.9142706394195557	seconds
# Dataframe and database updated in 0.019101619720458984 seconds
#
# Rows fetched: 1332500	in 2.884702205657959	seconds
# Dataframe and database updated in 0.017346620559692383 seconds
#
# Rows fetched: 1332750	in 4.500095844268799	seconds
# Dataframe and database updated in 0.018370389938354492 seconds
#
# Rows fetched: 1333000	in 3.5811421871185303	seconds
# Dataframe and database updated in 0.017403125762939453 seconds
#
# Rows fetched: 1333250	in 12.470812797546387	seconds
# Dataframe and database updated in 0.019138097763061523 seconds
#
# Rows fetched: 1333500	in 23.028162717819214	seconds
# Dataframe and database updated in 0.016931772232055664 seconds
#
# Rows fetched: 1333750	in 35.314008474349976	seconds
# Dataframe and database updated in 0.03008866310119629 seconds
#
# Rows fetched: 1334000	in 2.6981778144836426	seconds
# Dataframe and database updated in 0.01793646812438965 seconds
#
# Rows fetched: 1334250	in 2.4049394130706787	seconds
# Dataframe and database updated in 0.018683433532714844 seconds
#
# Rows fetched: 1334500	in 1.944610595703125	seconds
# Dataframe and database updated in 0.01898980140686035 seconds
#
# Rows fetched: 1334750	in 4.722373723983765	seconds
# Dataframe and database updated in 0.01625204086303711 seconds
#
# Rows fetched: 1335000	in 6.427226305007935	seconds
# Dataframe and database updated in 0.02266216278076172 seconds
#
# Rows fetched: 1335250	in 4.079144716262817	seconds
# Dataframe and database updated in 0.016811847686767578 seconds
#
# Rows fetched: 1335500	in 3.2329487800598145	seconds
# Dataframe and database updated in 0.017651081085205078 seconds
#
# Rows fetched: 1335750	in 3.6480226516723633	seconds
# Dataframe and database updated in 0.018259525299072266 seconds
#
# Rows fetched: 1336000	in 5.138930559158325	seconds
# Dataframe and database updated in 0.03769183158874512 seconds
#
# Rows fetched: 1336250	in 2.3414080142974854	seconds
# Dataframe and database updated in 0.01680779457092285 seconds
#
# Rows fetched: 1336500	in 3.039517402648926	seconds
# Dataframe and database updated in 0.01922321319580078 seconds
#
# Rows fetched: 1336750	in 5.681065559387207	seconds
# Dataframe and database updated in 0.01948857307434082 seconds
#
# Rows fetched: 1337000	in 2.9550669193267822	seconds
# Dataframe and database updated in 0.019502878189086914 seconds
#
# Rows fetched: 1337250	in 2.7096519470214844	seconds
# Dataframe and database updated in 0.01755523681640625 seconds
#
# Rows fetched: 1337500	in 3.9829492568969727	seconds
# Dataframe and database updated in 0.021091222763061523 seconds
#
# Rows fetched: 1337750	in 4.101644992828369	seconds
# Dataframe and database updated in 0.016837358474731445 seconds
#
# Rows fetched: 1338000	in 2.6224429607391357	seconds
# Dataframe and database updated in 0.03369569778442383 seconds
#
# Rows fetched: 1338250	in 8.25415325164795	seconds
# Dataframe and database updated in 0.020409107208251953 seconds
#
# Rows fetched: 1338500	in 3.1242146492004395	seconds
# Dataframe and database updated in 0.021730899810791016 seconds
#
# Rows fetched: 1338750	in 4.938704490661621	seconds
# Dataframe and database updated in 0.02203822135925293 seconds
#
# Rows fetched: 1339000	in 3.7471320629119873	seconds
# Dataframe and database updated in 0.016057491302490234 seconds
#
# Rows fetched: 1339250	in 6.113220691680908	seconds
# Dataframe and database updated in 0.01902484893798828 seconds
#
# Rows fetched: 1339500	in 3.319239854812622	seconds
# Dataframe and database updated in 0.016272544860839844 seconds
#
# Rows fetched: 1339750	in 6.022628307342529	seconds
# Dataframe and database updated in 0.018659591674804688 seconds
#
# Rows fetched: 1340000	in 4.273296117782593	seconds
# Dataframe and database updated in 0.021314620971679688 seconds
#
# Rows fetched: 1340250	in 7.254035472869873	seconds
# Dataframe and database updated in 0.03849482536315918 seconds
#
# Rows fetched: 1340500	in 7.046294450759888	seconds
# Dataframe and database updated in 0.017154455184936523 seconds
#
# Rows fetched: 1340750	in 9.797189712524414	seconds
# Dataframe and database updated in 0.023874282836914062 seconds
#
# Rows fetched: 1341000	in 5.167397737503052	seconds
# Dataframe and database updated in 0.020582914352416992 seconds
#
# Rows fetched: 1341250	in 3.759247303009033	seconds
# Dataframe and database updated in 0.019703388214111328 seconds

# %%
# closing the db connection
conn.close()
