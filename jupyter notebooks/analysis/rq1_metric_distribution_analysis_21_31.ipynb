# %% [markdown]
# # Imports and inits

# %%
import os
import numpy as np
import pandas as pd
import sqlite3
import json
from datetime import datetime, timedelta
from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

sns.set_style("whitegrid")

drive.mount('/content/gdrive/', force_remount=True)
os.chdir("/content/gdrive/Shareddrives/ECS 260/final")
# Out:
# Mounted at /content/gdrive/

# %%
# getting columns to analyze
with open('columns_to_analyze.txt', "r") as file:
  columns_to_analyze = file.read()
columns_to_analyze = json.loads(columns_to_analyze)
print(f"{len(columns_to_analyze)} columns to analyze:")
for i in range(len(columns_to_analyze)):
  column = columns_to_analyze[i]
  print(f"{i + 1} --> {column}")
# Out:
# 31 columns to analyze:
# 1 --> no_of_versions
# 2 --> no_of_users
# 3 --> has_readme
# 4 --> has_homepage
# 5 --> is_deprecated
# 6 --> no_of_dependencies
# 7 --> lagging_dependencies_count
# 8 --> unpack_size
# 9 --> file_count
# 10 --> has_repository
# 11 --> rank
# 12 --> dependants_count
# 13 --> dependant_repos_count
# 14 --> forks
# 15 --> stars
# 16 --> watchers
# 17 --> issues
# 18 --> pr
# 19 --> contributors
# 20 --> no_of_commits
# 21 --> avg_commit_freq
# 22 --> total_lines_of_code
# 23 --> sloc
# 24 --> no_of_files
# 25 --> health_score
# 26 --> security_numeric
# 27 --> popularity_numeric
# 28 --> maintenance_numeric
# 29 --> community_numeric
# 30 --> avg_monthly_download
# 31 --> days_since_last_modification

# %%
def get_df(query):
  conn = sqlite3.connect("final_database.db")
  cursor = conn.cursor()
  df = pd.read_sql_query(query, conn)
  conn.close()
  return df
def select_column(column):
  return f"SELECT {column} FROM package_data WHERE {column} IS NOT NULL"

# %%
# function to format each value in regular notation
def format_values(value):
  if isinstance(value, (int, float)):
    return "{:,.2f}".format(value)
  return value

# %%
def get_df_and_formatted_stats(column):
  df = get_df(select_column(column))
  formatted_stats = df.describe().apply(format_values)
  # display the formatted statistics
  print(formatted_stats)
  return df, formatted_stats

# %%
def visualize_distribution(df, column, outliers_removed=False):
  print("----------------------------------------------------------------------------------------------")
  fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 3))
  # plotting histogram
  sns.histplot(df, bins=30, kde=True, ax=axes[0])
  axes[0].set_title(f'Histogram of {column}' + ' (outliers removed)' if outliers_removed else '')
  axes[0].set_xlabel(f'{column}')
  axes[0].set_ylabel('Frequency')

  # plottin boxplot
  sns.boxplot(x=df, ax=axes[1])
  axes[1].set_title(f'Boxplot of {column}' + ' (outliers removed)' if outliers_removed else '')
  axes[1].set_xlabel(column)

  # plotting Q-Q plots
  stats.probplot(df, dist="norm", plot=axes[2])
  axes[2].set_title(f'Q-Q Plot of {column}' + ' (outliers removed)' if outliers_removed else '')

  # to ensures proper spacing between subplots
  plt.tight_layout()
  plt.show()

# %%
def remove_outliers(df, column):
  # taking care of outliers
  z_scores = stats.zscore(df[column])
  # setting threshold for Z-score
  threshold = 2.7
  # Filtering out rows with Z-scores beyond the threshold
  return df[(abs(z_scores) < threshold)]

def visualize_column(df, column):
  print("Observing original distributions")
  visualize_distribution(df[column], column)
  print("\n\n")

  print("Observing log distributions")
  visualize_distribution(np.log(df[column]), column)
  print("\n\n")


  # taking care of outliers
  z_scores = stats.zscore(df[column])
  # setting threshold for Z-score
  threshold = 2.7
  # Filtering out rows with Z-scores beyond the threshold
  outliers_removed_df = remove_outliers(df, column)

  print("Observing original distributions after taking care of outliers")
  visualize_distribution(outliers_removed_df[column], column, outliers_removed=True)
  print("\n\n")

  print("Observing log distributions after taking care of outliers")
  visualize_distribution(np.log(outliers_removed_df[column]), column, outliers_removed=True)
  print("\n\n")

# %% [markdown]
# # Column analyses

# %% [markdown]
# ###### Exploring column `avg_commit_freq`
# Used, after taking care of outliers and taking log
#
# To be used for triviality, activity

# %%
column = 'avg_commit_freq'
df, formatted_stats = get_df_and_formatted_stats(column)
print()
visualize_column(df, column)
# Out:
#        avg_commit_freq
# count     13406.000000
# mean          0.749893
# std          16.315194
# min          -3.000000
# 25%           0.005959
# 50%           0.024105
# 75%           0.131864
# max        1315.937500
#
# Observing original distributions
# ----------------------------------------------------------------------------------------------
# Observing log distributions
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Observing original distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# Observing log distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ###### Exploring column `total_lines_of_code`
# Used, after taking log
#
# To be used for triviality

# %%
column = 'total_lines_of_code'
df, formatted_stats = get_df_and_formatted_stats(column)
print()
visualize_column(df, column)
# Out:
#        total_lines_of_code
# count         1.337600e+04
# mean          2.226858e+05
# std           1.677187e+06
# min          -6.280540e+06
# 25%           6.977500e+02
# 50%           5.024000e+03
# 75%           2.085550e+04
# max           2.989502e+07
#
# Observing original distributions
# ----------------------------------------------------------------------------------------------
# Observing log distributions
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Observing original distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# Observing log distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ###### Exploring column `sloc`
# Used, after taking log
#
# To be used for triviality

# %%
column = 'sloc'
df, formatted_stats = get_df_and_formatted_stats(column)
print()
visualize_column(df, column)
# Out:
#                sloc
# count  1.337600e+04
# mean   1.804644e+05
# std    1.584421e+06
# min   -6.316988e+06
# 25%    2.900000e+01
# 50%    2.890000e+02
# 75%    6.936000e+03
# max    2.987894e+07
#
# Observing original distributions
# ----------------------------------------------------------------------------------------------
# Observing log distributions
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Observing original distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# Observing log distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ###### Exploring column `no_of_files`
#
# Used, after taking care of outliers and taking log
#
# To be used for triviality

# %%
column = 'no_of_files'
df, formatted_stats = get_df_and_formatted_stats(column)
print()
visualize_column(df, column)
# Out:
#         no_of_files
# count  1.337600e+04
# mean   5.345846e+03
# std    9.695064e+04
# min   -6.316988e+06
# 25%    2.000000e+01
# 50%    8.500000e+01
# 75%    7.082500e+02
# max    4.869853e+06
#
# Observing original distributions
# ----------------------------------------------------------------------------------------------
# Observing log distributions
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Observing original distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# Observing log distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ###### Exploring column `health_score`
# Used, after taking care of outliers
#
# To be used for RQ3

# %%
column = 'health_score'
df, formatted_stats = get_df_and_formatted_stats(column)
print()
visualize_column(df, column)
# Out:
#        health_score
# count  29284.000000
# mean      42.976779
# std        9.983592
# min        0.000000
# 25%       39.000000
# 50%       42.000000
# 75%       46.000000
# max      100.000000
#
# Observing original distributions
# ----------------------------------------------------------------------------------------------
# Observing log distributions
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# Observing original distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# Observing log distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# ###### Exploring column `security_numeric`
#
# Used
#
# To be used for RQ3

# %%
column = 'security_numeric'
df, formatted_stats = get_df_and_formatted_stats(column)
print()
visualize_column(df, column)
# Out:
#        security_numeric
# count      29283.000000
# mean          82.743913
# std           24.926109
# min            0.000000
# 25%           50.000000
# 50%          100.000000
# 75%          100.000000
# max          100.000000
#
# Observing original distributions
# ----------------------------------------------------------------------------------------------
# Observing log distributions
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# Observing original distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# Observing log distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# ###### Exploring column `popularity_numeric`
#
# Used
#
# To be used for RQ3

# %%
column = 'popularity_numeric'
df, formatted_stats = get_df_and_formatted_stats(column)
print()
visualize_column(df, column)
# Out:
#        popularity_numeric
# count        29284.000000
# mean            20.185084
# std              6.701231
# min              0.000000
# 25%             20.000000
# 50%             20.000000
# 75%             20.000000
# max            100.000000
#
# Observing original distributions
# ----------------------------------------------------------------------------------------------
# Observing log distributions
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# Observing original distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# Observing log distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# ###### Exploring column `maintenance_numeric`
# Used
#
# To be used for RQ3

# %%
column = 'maintenance_numeric'
df, formatted_stats = get_df_and_formatted_stats(column)
print()
visualize_column(df, column)
# Out:
#        maintenance_numeric
# count         29284.000000
# mean             11.743785
# std              18.681552
# min               0.000000
# 25%               5.000000
# 50%               5.000000
# 75%               5.000000
# max             100.000000
#
# Observing original distributions
# ----------------------------------------------------------------------------------------------
# Observing log distributions
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# Observing original distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# Observing log distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]

# %% [markdown]
# ###### Exploring column `community_numeric`
#
# Used
#
# To be used for RQ3

# %%
column = 'community_numeric'
df, formatted_stats = get_df_and_formatted_stats(column)
print()
visualize_column(df, column)
# Out:
#        community_numeric
# count       29284.000000
# mean           22.445363
# std            11.856044
# min             0.000000
# 25%            20.000000
# 50%            20.000000
# 75%            20.000000
# max           100.000000
#
# Observing original distributions
# ----------------------------------------------------------------------------------------------
# Observing log distributions
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# Observing original distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# Observing log distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]

# %% [markdown]
# ###### Exploring column `avg_monthly_download`
# Not useful to define any meaningful state

# %%
column = 'avg_monthly_download'
df, formatted_stats = get_df_and_formatted_stats(column)
print()
visualize_column(df, column)
# Out:
#        avg_monthly_download
# count          2.958200e+04
# mean           6.984283e+04
# std            2.216444e+06
# min            0.000000e+00
# 25%            5.000000e+00
# 50%            1.100000e+01
# 75%            3.800000e+01
# max            1.801845e+08
#
# Observing original distributions
# ----------------------------------------------------------------------------------------------
# Observing log distributions
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# Observing original distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# Observing log distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]

# %% [markdown]
# ###### Exploring column `days_since_last_modification`
#
# Used
#
# To be used for defining dead state

# %%
column = 'days_since_last_modification'
df, formatted_stats = get_df_and_formatted_stats(column)
print()
visualize_column(df, column)
# Out:
#        days_since_last_modification
# count                  29792.000000
# mean                     502.292461
# std                      224.520249
# min                      -10.000000
# 25%                      352.000000
# 50%                      614.000000
# 75%                      656.000000
# max                     3860.000000
#
# Observing original distributions
# ----------------------------------------------------------------------------------------------
# Observing log distributions
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Observing original distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# Observing log distributions after taking care of outliers
# ----------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# # Adding finalized columns to new table `package_metrics`

# %%
def add_column_if_not_exists(cursor, table_name, column_name, column_definition):
  # check if the column already exists
  cursor.execute(f"PRAGMA table_info({table_name});")
  existing_columns = [column[1] for column in cursor.fetchall()]

  if column_name not in existing_columns:
    # add the column if it does not exist
    cursor.execute(f"ALTER TABLE {table_name} ADD COLUMN {column_name} {column_definition};")

# %%
conn = sqlite3.connect("final_database.db")
cursor = conn.cursor()
cursor.execute("""
    CREATE TABLE IF NOT EXISTS package_metrics (
        package TEXT
    )
""")

conn.commit()

# %%
with open('columns_to_consider.txt', "r") as file:
  columns_to_consider = file.read()

columns_to_consider = json.loads(columns_to_consider)
n_cols = len(columns_to_consider)

# columns other than `package`
columns = [[metric, 'TEXT DEFAULT NULL'] for metric in columns_to_consider]

# adding columns to the table
for col in columns:
  add_column_if_not_exists(cursor, 'package_metrics', col[0], col[1])

conn.commit()
sql_query = """
    INSERT INTO package_metrics (package)
    SELECT p.package
    FROM package_data p
    LEFT JOIN package_metrics m ON p.package = m.package
    WHERE m.package IS NULL
"""
cursor.execute(sql_query)
conn.commit()
pd.read_sql_query(f"SELECT * FROM package_metrics", conn)
# Out:
#                             package  rank   dependants_count  \
# 0         @gerrico/react-components  None   1.09861228866811
# 1      express-simple-app-generator   6.0                0.0
# 2                 generator-giraffe  10.0                0.0
# 3                   outdated-client   3.0  0.693147180559945
# 4      @semi-bot/semi-theme-shopify  None               None
# ...                             ...   ...                ...
# 29995                    haribotify  10.0    1.6094379124341
# 29996        eslint-config-sharecar   7.0                0.0
# 29997              webpack-to-ardoq   4.0                0.0
# 29998         zywave-content-search   3.0                0.0
# 29999                      ngdoc-md   9.0  0.693147180559945
#
#       dependant_repos_count             forks              stars  \
# 0          1.09861228866811               0.0                0.0
# 1                       0.0              None               None
# 2          1.09861228866811               0.0  0.693147180559945
# 3                       0.0              None               None
# 4                      None              None               None
# ...                     ...               ...                ...
# 29995                   0.0              None               None
# 29996      1.38629436111989               0.0                0.0
# 29997                   0.0              None               None
# 29998                   0.0              None               None
# 29999      1.09861228866811  1.09861228866811   1.09861228866811
#
#                 watchers issues    pr contributors  ... total_lines_of_code  \
# 0                    0.0    0.0   0.0          0.0  ...    7.39756153552405
# 1                   None   None  None         None  ...                None
# 2                    0.0    0.0   0.0          0.0  ...    8.23615566168312
# 3                   None   None  None         None  ...                None
# 4                   None   None  None         None  ...                None
# ...                  ...    ...   ...          ...  ...                 ...
# 29995               None   None  None         None  ...                None
# 29996                0.0    0.0   0.0          0.0  ...    7.44541755670169
# 29997               None   None  None         None  ...                None
# 29998               None   None  None         None  ...                None
# 29999  0.693147180559945    1.0   0.0          0.0  ...    6.71417052990947
#
#                    sloc       no_of_files health_score security_numeric  \
# 0      7.38025578842646  3.43398720448515         30.0             50.0
# 1                  None              None         54.0            100.0
# 2      7.19443685110033  4.34380542185368         36.0             50.0
# 3                  None              None         28.0             50.0
# 4                  None              None         40.0            100.0
# ...                 ...               ...          ...              ...
# 29995              None              None         42.0            100.0
# 29996  1.94591014905531  4.02535169073515         42.0            100.0
# 29997              None              None         40.0             50.0
# 29998              None              None         28.0             50.0
# 29999  5.38449506278909  3.49650756146648         36.0             50.0
#
#       popularity_numeric maintenance_numeric community_numeric  \
# 0                   20.0                 5.0              20.0
# 1                   20.0                50.0              20.0
# 2                   20.0                 5.0              20.0
# 3                   20.0                 5.0              20.0
# 4                   20.0                 5.0              20.0
# ...                  ...                 ...               ...
# 29995               20.0                 5.0              20.0
# 29996               20.0                 5.0              20.0
# 29997               10.0                 5.0              20.0
# 29998               20.0                 5.0              20.0
# 29999               20.0                 5.0              20.0
#
#       days_since_last_modification is_deprecated
# 0                            559.0             0
# 1                            149.0             0
# 2                            614.0             0
# 3                            651.0             0
# 4                            561.0             0
# ...                            ...           ...
# 29995                        614.0             0
# 29996                        615.0             0
# 29997                        134.0             0
# 29998                        638.0             0
# 29999                        611.0             0
#
# [30000 rows x 27 columns]

# %%
def update_column_data(column, outliers_removed = False, take_log = False):
  df = get_df(f"SELECT package, {column} FROM package_data WHERE {column} IS NOT NULL")
  df[column] = df[column].astype(float)


  if outliers_removed:
    z_scores = stats.zscore(df[column])
    threshold = 2.7
    df = df[(abs(z_scores) < threshold)]

  if take_log:
    df[column] = np.where(df[column] > 0, np.log(df[column]), np.log1p(df[column]))

  df.to_sql('temp_table', conn, if_exists='replace', index=False)

  cursor.execute("""
      UPDATE package_metrics
      SET {column} = t.{column}
      FROM temp_table AS t
      WHERE package_metrics.package = t.package
  """.format(column=column))
  conn.commit()

# %%
update_column_data('avg_commit_freq', outliers_removed = True, take_log = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
update_column_data('total_lines_of_code', take_log = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
update_column_data('sloc', take_log = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
update_column_data('no_of_files', outliers_removed = True, take_log = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
update_column_data('health_score', outliers_removed = True)

# %%
update_column_data('security_numeric')

# %%
update_column_data('popularity_numeric')

# %%
update_column_data('maintenance_numeric')

# %%
update_column_data('community_numeric')

# %%
update_column_data('days_since_last_modification')

# %%
conn.close()
